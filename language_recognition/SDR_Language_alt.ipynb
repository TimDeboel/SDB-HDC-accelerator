# %%
import numpy as np
import os

# %%
###############################################
# Set parameters
###############################################
D = 10000
M = 100    # Number of ones
N = 3       # Sliding window size
print("Density: " + str(M/D))
# Out:
# Density: 0.01

# %%
def u_gen_rand_hv(D):

    # Sanity checker
    if (D % 2):
        print("Error - D can't be an odd number")
        return 0

    hv = np.zeros(D, dtype = int)
    indices = np.random.permutation(D)

    hv[indices >= M] = 0
    hv[indices < M] = 1

    return hv

# %%
def cos_angle(u,v):
    return np.dot(u,v)/(np.linalg.norm(u)*np.linalg.norm(v))

# %% [markdown]
# # Encoding

# %%
def lookup_item_mem(item_memory, key, D):
    if (item_memory.get(key) is not None):
        value = item_memory[key]
    else:
        value = u_gen_rand_hv(D)
        item_memory[key] = value
    return item_memory, value

# %%
def binarize_hv(v, final_density):
    sort_array = np.copy(v)
    sort_array[::-1].sort()
    cutoff = round(len(v)*final_density)
    threshold = sort_array[cutoff]
    print("Cutoff: " + str(cutoff))
    
    for i in range(len(v)):
        if v[i] > threshold:
            v[i] = 1
        else:
            v[i] = 0
    return v

# %%
def window_sum(buffer, letters_im, N, D):
    block = np.zeros((N, D), dtype = int)
    sum_hv = np.zeros(D, dtype = int)
    for i in range(len(buffer)):
        block = np.roll(block, (1, 1), axis=(1, 0))
        letters_im, block[0] = lookup_item_mem(letters_im, buffer[i], D)
        
        if i >= (N-1):
            n_grams = block[0]
            for j in range(1,N):
                # n_grams = np.logical_xor(n_grams, block[j])
                n_grams = n_grams + block[j]
            n_grams = binarize_hv(n_grams, 0.5)
            sum_hv = sum_hv + n_grams
            # sum_hv = np.logical_or(sum_hv,n_grams)
    
    THR = 0.2
    sum_hv = binarize_hv(sum_hv, THR)
    print('Density after sum: ' + str(np.sum(sum_hv)/len(sum_hv)))
    # print(np.sum(sum_hv)/len(sum_hv))

    # K = 1
    # thinned_list = []
    # for k in range(1,K+1):
    #     thinned_list.append(np.logical_and(sum_hv, np.roll(sum_hv,k)))
    # thinned_sum = np.array([1 if x >= 1 else 0 for x in sum(thinned_list)])

    # print('density after cdt: ' + str(np.sum(thinned_sum)/len(thinned_sum)))       
    return letters_im, sum_hv

# %%
def binarize_language_hv(lang_am, buffer_len):
    lang_labels = ['afr', 'bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    for j in lang_labels:
        v = lang_am[j]
        lang_am[j] = binarize_hv(v, buffer_len)
    return lang_am

# %% [markdown]
# # Training

# %%
def build_memories(N, D):
    item_mem = dict()
    lang_am = dict()
    lang_labels = ['afr', 'bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    # lang_labels = ['afr', 'bul']

    for i in lang_labels:
        print('Reading file: ' + i)
        file_address = './training_texts/' + i + '.txt'
        with open(file_address) as f:
            buffer = f.read()

        item_mem, lang_hv = window_sum(buffer, item_mem, N, D)
        # lang_am[i] = binarize_hv(lang_hv, len(buffer))
        lang_am[i] = lang_hv
        
    return item_mem, lang_am

# %%
def test(item_mem, lang_am, N, D):
    total = 0
    correct = 0
    lang_labels = ['afr', 'bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    lang_map = dict()
    lang_map['af'] = 'afr'
    lang_map['bg'] = 'bul'
    lang_map['cs'] = 'ces'
    lang_map['da'] = 'dan'
    lang_map['nl'] = 'nld'
    lang_map['de'] = 'deu'
    lang_map['en'] = 'eng'
    lang_map['et'] = 'est'
    lang_map['fi'] = 'fin'
    lang_map['fr'] = 'fra'
    lang_map['el'] = 'ell'
    lang_map['hu'] = 'hun'
    lang_map['it'] = 'ita'
    lang_map['lv'] = 'lav'
    lang_map['lt'] = 'lit'
    lang_map['pl'] = 'pol'
    lang_map['pt'] = 'por'
    lang_map['ro'] = 'ron'
    lang_map['sk'] = 'slk'
    lang_map['sl'] = 'slv'
    lang_map['es'] = 'spa'
    lang_map['sv'] = 'swe'

    for file in os.listdir('./testing_texts/'):
        if file.endswith('.txt'):
            actual_label = file[0:2]
            predict_lang = ''

            file_address = './testing_texts/' + file
            with open(file_address) as f:
                buffer = f.read()
            print('Loaded testing text file: ' + str(file_address))

            item_mem_n, text_hv = window_sum(buffer, item_mem, N, D)
            # text_hv = binarize_hv(text_hv, len(buffer))
            if (item_mem != item_mem_n):
                print('\n>>>> NEW UNSEEN ITEM IN TEST FILE <<<<\n')
                exit()
            else:
                max_angle = -1
                # max_angle = 10000
                for j in range(len(lang_labels)):
                    if (lang_labels[j] in lang_am.keys()):
                        angle = cos_angle(lang_am[lang_labels[j]], text_hv)
                        # angle = np.sum(np.logical_xor(lang_am[lang_labels[j]], text_hv))
                        if (angle > max_angle):
                        # if (angle < max_angle):
                            max_angle = angle
                            predict_lang = lang_labels[j]
                
                if (predict_lang == lang_map[actual_label]):
                    correct += 1
                else:
                    print(str(lang_map[actual_label]) + '-->' + predict_lang)
                total += 1
    return correct / total

# %%
item_mem, lang_am = build_memories(N,D)
# Out:
# Reading file: afr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\timde\repos\thesis\language_recognition\SDR_Language_alt.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> item_mem, lang_am = build_memories(N,D)
#
# c:\Users\timde\repos\thesis\language_recognition\SDR_Language_alt.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a> with open(file_address) as f:
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a>     buffer = f.read()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> item_mem, lang_hv = window_sum(buffer, item_mem, N, D)
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> # lang_am[i] = binarize_hv(lang_hv, len(buffer))
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a> lang_am[i] = lang_hv
#
# c:\Users\timde\repos\thesis\language_recognition\SDR_Language_alt.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a> for j in range(1,N):
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a>     # n_grams = np.logical_xor(n_grams, block[j])
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a>     n_grams = n_grams + block[j]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> n_grams = binarize_hv(n_grams, 0.5)
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> sum_hv = sum_hv + n_grams
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a> # sum_hv = np.logical_or(sum_hv,n_grams)
#
# c:\Users\timde\repos\thesis\language_recognition\SDR_Language_alt.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> def binarize_hv(v, final_density):
#       <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a>     sort_array = np.copy(v)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a>     sort_array[::-1].sort()
#       <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a>     cutoff = round(len(v)*final_density)
#       <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_alt.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     threshold = sort_array[cutoff]
#
# KeyboardInterrupt:

# %%
np.save('item_mem1.npy', item_mem)
np.save('lang_am1.npy', lang_am)
# item_mem2 = np.load('item_mem1.npy', allow_pickle='TRUE').item()

# %%
test(item_mem, lang_am, N, D)
# Out:
# Loaded testing text file: ./testing_texts/bg_0_p.txt
# density after cdt: 0.3251
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_100_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_101_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_102_p.txt
# density after cdt: 0.3501
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_103_p.txt
# density after cdt: 0.3634
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_104_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_105_p.txt
# density after cdt: 0.3374
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_106_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_107_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_108_p.txt
# density after cdt: 0.336
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_109_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_10_p.txt
# density after cdt: 0.322
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_110_p.txt
# density after cdt: 0.3597
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_111_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_112_p.txt
# density after cdt: 0.3378
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_113_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_114_p.txt
# density after cdt: 0.2772
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_115_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_116_p.txt
# density after cdt: 0.3653
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_117_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_118_p.txt
# density after cdt: 0.3251
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_119_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_11_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_120_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_121_p.txt
# density after cdt: 0.3102
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_122_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_123_p.txt
# density after cdt: 0.3511
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_124_p.txt
# density after cdt: 0.3803
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_125_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_126_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_127_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_128_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_129_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_12_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_130_p.txt
# density after cdt: 0.3545
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_131_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_132_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_133_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_134_p.txt
# density after cdt: 0.3093
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_135_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_136_p.txt
# density after cdt: 0.3062
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_137_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_138_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_139_p.txt
# density after cdt: 0.3221
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_13_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_140_p.txt
# density after cdt: 0.3215
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_141_p.txt
# density after cdt: 0.321
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_142_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_143_p.txt
# density after cdt: 0.3365
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_144_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_145_p.txt
# density after cdt: 0.3377
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_146_p.txt
# density after cdt: 0.3392
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_147_p.txt
# density after cdt: 0.3518
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_148_p.txt
# density after cdt: 0.3667
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_149_p.txt
# density after cdt: 0.3346
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_14_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_150_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_151_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_152_p.txt
# density after cdt: 0.2886
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_153_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_154_p.txt
# density after cdt: 0.3302
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_155_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_156_p.txt
# density after cdt: 0.3375
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_157_p.txt
# density after cdt: 0.3362
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_158_p.txt
# density after cdt: 0.3368
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_159_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_15_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_160_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_161_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_162_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_163_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_164_p.txt
# density after cdt: 0.3084
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_165_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_166_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_167_p.txt
# density after cdt: 0.3524
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_168_p.txt
# density after cdt: 0.3383
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_169_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_16_p.txt
# density after cdt: 0.3957
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_170_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_171_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_172_p.txt
# density after cdt: 0.3057
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_173_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_174_p.txt
# density after cdt: 0.2016
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_175_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_176_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_177_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_178_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_179_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_17_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_180_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_181_p.txt
# density after cdt: 0.3322
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_182_p.txt
# density after cdt: 0.3218
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_183_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_184_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_185_p.txt
# density after cdt: 0.3381
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_186_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_187_p.txt
# density after cdt: 0.3365
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_188_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_189_p.txt
# density after cdt: 0.3378
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_18_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_190_p.txt
# density after cdt: 0.3511
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_191_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_192_p.txt
# density after cdt: 0.3348
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_193_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_194_p.txt
# density after cdt: 0.3524
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_195_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_196_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_197_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_198_p.txt
# density after cdt: 0.3385
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_199_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_19_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_1_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_200_p.txt
# density after cdt: 0.3226
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_201_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_202_p.txt
# density after cdt: 0.2079
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_203_p.txt
# density after cdt: 0.3378
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_204_p.txt
# density after cdt: 0.3368
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_205_p.txt
# density after cdt: 0.3381
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_206_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_207_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_208_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_209_p.txt
# density after cdt: 0.3383
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_20_p.txt
# density after cdt: 0.3009
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_210_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_211_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_212_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_213_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_214_p.txt
# density after cdt: 0.2981
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_215_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_216_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_217_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_218_p.txt
# density after cdt: 0.3699
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_219_p.txt
# density after cdt: 0.3511
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_21_p.txt
# density after cdt: 0.3309
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_220_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_221_p.txt
# density after cdt: 0.3287
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_222_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_223_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_224_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_225_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_226_p.txt
# density after cdt: 0.3237
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_227_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_228_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_229_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_22_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_230_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_231_p.txt
# density after cdt: 0.3384
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_232_p.txt
# density after cdt: 0.3673
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_233_p.txt
# density after cdt: 0.3525
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_234_p.txt
# density after cdt: 0.3069
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_235_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_236_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_237_p.txt
# density after cdt: 0.3526
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_238_p.txt
# density after cdt: 0.3388
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_239_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_23_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_240_p.txt
# density after cdt: 0.3537
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_241_p.txt
# density after cdt: 0.2471
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_242_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_243_p.txt
# density after cdt: 0.3536
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_244_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_245_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_246_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_247_p.txt
# density after cdt: 0.3226
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_248_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_249_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_24_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_250_p.txt
# density after cdt: 0.274
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_251_p.txt
# density after cdt: 0.3673
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_252_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_253_p.txt
# density after cdt: 0.3515
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_254_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_255_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_256_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_257_p.txt
# density after cdt: 0.291
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_258_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_259_p.txt
# density after cdt: 0.3667
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_25_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_260_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_261_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_262_p.txt
# density after cdt: 0.3335
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_263_p.txt
# density after cdt: 0.2769
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_264_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_265_p.txt
# density after cdt: 0.337
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_266_p.txt
# density after cdt: 0.3673
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_267_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_268_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_269_p.txt
# density after cdt: 0.3667
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_26_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_270_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_271_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_272_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_273_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_274_p.txt
# density after cdt: 0.3222
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_275_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_276_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_277_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_278_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_279_p.txt
# density after cdt: 0.2654
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_27_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_280_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_281_p.txt
# density after cdt: 0.3219
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_282_p.txt
# density after cdt: 0.243
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_283_p.txt
# density after cdt: 0.3071
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_284_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_285_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_286_p.txt
# density after cdt: 0.3371
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_287_p.txt
# density after cdt: 0.3368
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_288_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_289_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_28_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_290_p.txt
# density after cdt: 0.3376
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_291_p.txt
# density after cdt: 0.323
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_292_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_293_p.txt
# density after cdt: 0.3662
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_294_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_295_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_296_p.txt
# density after cdt: 0.3388
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_297_p.txt
# density after cdt: 0.2879
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_298_p.txt
# density after cdt: 0.3368
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_299_p.txt
# density after cdt: 0.2783
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_29_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_2_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_300_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_301_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_302_p.txt
# density after cdt: 0.3524
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_303_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_304_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_305_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_306_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_307_p.txt
# density after cdt: 0.2748
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_308_p.txt
# density after cdt: 0.3673
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_309_p.txt
# density after cdt: 0.3517
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_30_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_310_p.txt
# density after cdt: 0.3667
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_311_p.txt
# density after cdt: 0.337
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_312_p.txt
# density after cdt: 0.323
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_313_p.txt
# density after cdt: 0.3229
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_314_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_315_p.txt
# density after cdt: 0.291
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_316_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_317_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_318_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_319_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_31_p.txt
# density after cdt: 0.2909
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_320_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_321_p.txt
# density after cdt: 0.3526
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_322_p.txt
# density after cdt: 0.3387
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_323_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_324_p.txt
# density after cdt: 0.2766
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_325_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_326_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_327_p.txt
# density after cdt: 0.2984
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_328_p.txt
# density after cdt: 0.3056
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_329_p.txt
# density after cdt: 0.2755
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_32_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_330_p.txt
# density after cdt: 0.3655
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_331_p.txt
# density after cdt: 0.3667
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_332_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_333_p.txt
# density after cdt: 0.3387
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_334_p.txt
# density after cdt: 0.276
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_335_p.txt
# density after cdt: 0.3526
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_336_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_337_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_338_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_339_p.txt
# density after cdt: 0.3657
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_33_p.txt
# density after cdt: 0.3001
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_340_p.txt
# density after cdt: 0.3245
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_341_p.txt
# density after cdt: 0.3063
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_342_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_343_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_344_p.txt
# density after cdt: 0.3368
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_345_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_346_p.txt
# density after cdt: 0.2737
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_347_p.txt
# density after cdt: 0.2769
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_348_p.txt
# density after cdt: 0.3404
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_349_p.txt
# density after cdt: 0.3242
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_34_p.txt
# density after cdt: 0.3387
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_350_p.txt
# density after cdt: 0.3227
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_351_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_352_p.txt
# density after cdt: 0.3041
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_353_p.txt
# density after cdt: 0.3228
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_354_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_355_p.txt
# density after cdt: 0.3089
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_356_p.txt
# density after cdt: 0.338
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_357_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_358_p.txt
# density after cdt: 0.3221
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_359_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_35_p.txt
# density after cdt: 0.3068
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_360_p.txt
# density after cdt: 0.3149
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_361_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_362_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_363_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_364_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_365_p.txt
# density after cdt: 0.3197
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_366_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_367_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_368_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_369_p.txt
# density after cdt: 0.3368
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_36_p.txt
# density after cdt: 0.3786
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_370_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_371_p.txt
# density after cdt: 0.307
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_372_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_373_p.txt
# density after cdt: 0.3207
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_374_p.txt
# density after cdt: 0.3221
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_375_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_376_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_377_p.txt
# density after cdt: 0.3676
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_378_p.txt
# density after cdt: 0.3376
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_379_p.txt
# density after cdt: 0.2591
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_37_p.txt
# density after cdt: 0.302
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_380_p.txt
# density after cdt: 0.3189
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_381_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_382_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_383_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_384_p.txt
# density after cdt: 0.3667
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_385_p.txt
# density after cdt: 0.3229
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_386_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_387_p.txt
# density after cdt: 0.3517
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_388_p.txt
# density after cdt: 0.3667
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_389_p.txt
# density after cdt: 0.3365
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_38_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_390_p.txt
# density after cdt: 0.3383
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_391_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_392_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_393_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_394_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_395_p.txt
# density after cdt: 0.3673
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_396_p.txt
# density after cdt: 0.336
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_397_p.txt
# density after cdt: 0.3526
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_398_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_399_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_39_p.txt
# density after cdt: 0.3216
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_3_p.txt
# density after cdt: 0.3309
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_400_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_401_p.txt
# density after cdt: 0.3526
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_402_p.txt
# density after cdt: 0.3239
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_403_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_404_p.txt
# density after cdt: 0.3086
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_405_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_406_p.txt
# density after cdt: 0.3208
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_407_p.txt
# density after cdt: 0.3369
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_408_p.txt
# density after cdt: 0.3499
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_409_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_40_p.txt
# density after cdt: 0.288
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_410_p.txt
# density after cdt: 0.3381
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_411_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_412_p.txt
# density after cdt: 0.3378
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_413_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_414_p.txt
# density after cdt: 0.3518
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_415_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_416_p.txt
# density after cdt: 0.3228
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_417_p.txt
# density after cdt: 0.3396
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_418_p.txt
# density after cdt: 0.367
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_419_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_41_p.txt
# density after cdt: 0.3066
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_420_p.txt
# density after cdt: 0.2742
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_421_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_422_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_423_p.txt
# density after cdt: 0.3383
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_424_p.txt
# density after cdt: 0.336
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_425_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_426_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_427_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_428_p.txt
# density after cdt: 0.3232
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_429_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_42_p.txt
# density after cdt: 0.3938
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_430_p.txt
# density after cdt: 0.3089
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_431_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_432_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_433_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_434_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_435_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_436_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_437_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_438_p.txt
# density after cdt: 0.3378
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_439_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_43_p.txt
# density after cdt: 0.3514
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_440_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_441_p.txt
# density after cdt: 0.2763
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_442_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_443_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_444_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_445_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_446_p.txt
# density after cdt: 0.2928
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_447_p.txt
# density after cdt: 0.3375
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_448_p.txt
# density after cdt: 0.3226
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_449_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_44_p.txt
# density after cdt: 0.3218
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_450_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_451_p.txt
# density after cdt: 0.3526
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_452_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_453_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_454_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_455_p.txt
# density after cdt: 0.3053
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_456_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_457_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_458_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_459_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_45_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_460_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_461_p.txt
# density after cdt: 0.3062
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_462_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_463_p.txt
# density after cdt: 0.3811
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_464_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_465_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_466_p.txt
# density after cdt: 0.3392
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_467_p.txt
# density after cdt: 0.3215
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_468_p.txt
# density after cdt: 0.3218
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_469_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_46_p.txt
# density after cdt: 0.3595
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_470_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_471_p.txt
# density after cdt: 0.3381
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_472_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_473_p.txt
# density after cdt: 0.2931
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_474_p.txt
# density after cdt: 0.3673
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_475_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_476_p.txt
# density after cdt: 0.3533
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_477_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_478_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_479_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_47_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_480_p.txt
# density after cdt: 0.366
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_481_p.txt
# density after cdt: 0.3511
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_482_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_483_p.txt
# density after cdt: 0.338
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_484_p.txt
# density after cdt: 0.1876
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_485_p.txt
# density after cdt: 0.3387
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_486_p.txt
# density after cdt: 0.3379
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_487_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_488_p.txt
# density after cdt: 0.2894
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_489_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_48_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_490_p.txt
# density after cdt: 0.3526
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_491_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_492_p.txt
# density after cdt: 0.3376
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_493_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_494_p.txt
# density after cdt: 0.3221
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_495_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_496_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_497_p.txt
# density after cdt: 0.3381
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_498_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_499_p.txt
# density after cdt: 0.3376
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_49_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_4_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_500_p.txt
# density after cdt: 0.276
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_501_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_502_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_503_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_504_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_505_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_506_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_507_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_508_p.txt
# density after cdt: 0.3219
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_509_p.txt
# density after cdt: 0.3511
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_50_p.txt
# density after cdt: 0.3381
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_510_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_511_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_512_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_513_p.txt
# density after cdt: 0.3219
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_514_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_515_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_516_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_517_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_518_p.txt
# density after cdt: 0.3091
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_519_p.txt
# density after cdt: 0.3376
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_51_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_520_p.txt
# density after cdt: 0.3382
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_521_p.txt
# density after cdt: 0.3523
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_522_p.txt
# density after cdt: 0.2838
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_523_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_524_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_525_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_526_p.txt
# density after cdt: 0.2512
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_527_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_528_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_529_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_52_p.txt
# density after cdt: 0.2906
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_530_p.txt
# density after cdt: 0.3236
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_531_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_532_p.txt
# density after cdt: 0.3242
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_533_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_534_p.txt
# density after cdt: 0.3221
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_535_p.txt
# density after cdt: 0.3235
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_536_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_537_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_538_p.txt
# density after cdt: 0.3381
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_539_p.txt
# density after cdt: 0.3203
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_53_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_540_p.txt
# density after cdt: 0.3378
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_541_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_542_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_543_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_544_p.txt
# density after cdt: 0.269
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_545_p.txt
# density after cdt: 0.3209
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_546_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_547_p.txt
# density after cdt: 0.3071
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_548_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_549_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_54_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_550_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_551_p.txt
# density after cdt: 0.3218
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_552_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_553_p.txt
# density after cdt: 0.3524
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_554_p.txt
# density after cdt: 0.337
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_555_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_556_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_557_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_558_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_559_p.txt
# density after cdt: 0.3678
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_55_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_560_p.txt
# density after cdt: 0.3214
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_561_p.txt
# density after cdt: 0.3065
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_562_p.txt
# density after cdt: 0.3373
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_563_p.txt
# density after cdt: 0.352
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_564_p.txt
# density after cdt: 0.3071
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_565_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_566_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_567_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_568_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_569_p.txt
# density after cdt: 0.3519
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_56_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_570_p.txt
# density after cdt: 0.3664
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_571_p.txt
# density after cdt: 0.3521
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_572_p.txt
# density after cdt: 0.3207
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_573_p.txt
# density after cdt: 0.3805
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_574_p.txt
# density after cdt: 0.3197
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_575_p.txt
# density after cdt: 0.3219
# bul-->afr
# Loaded testing text file: ./testing_texts/bg_576_p.txt
# ...
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_124_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_125_p.txt
# density after cdt: 0.3362
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_126_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_127_p.txt
# density after cdt: 0.3525
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_128_p.txt
# density after cdt: 0.3204
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_129_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_12_p.txt
# density after cdt: 0.3937
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_130_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_131_p.txt
# density after cdt: 0.3665
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_132_p.txt
# density after cdt: 0.3665
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_133_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_134_p.txt
# density after cdt: 0.3665
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_135_p.txt
# density after cdt: 0.3665
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_136_p.txt
# density after cdt: 0.3794
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_137_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_138_p.txt
# density after cdt: 0.3749
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_139_p.txt
# density after cdt: 0.3809
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_13_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_140_p.txt
# density after cdt: 0.4074
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_141_p.txt
# density after cdt: 0.323
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_142_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_143_p.txt
# density after cdt: 0.3942
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_144_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_145_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_146_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_147_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_148_p.txt
# density after cdt: 0.3942
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_149_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_14_p.txt
# density after cdt: 0.3942
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_150_p.txt
# density after cdt: 0.3809
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_151_p.txt
# density after cdt: 0.3529
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_152_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_153_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_154_p.txt
# density after cdt: 0.3681
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_155_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_156_p.txt
# density after cdt: 0.3804
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_157_p.txt
# density after cdt: 0.2777
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_158_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_159_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_15_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_160_p.txt
# density after cdt: 0.3928
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_161_p.txt
# density after cdt: 0.3804
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_162_p.txt
# density after cdt: 0.3074
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_163_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_164_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_165_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_166_p.txt
# density after cdt: 0.3936
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_167_p.txt
# density after cdt: 0.3217
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_168_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_169_p.txt
# density after cdt: 0.2991
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_16_p.txt
# density after cdt: 0.3938
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_170_p.txt
# density after cdt: 0.3681
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_171_p.txt
# density after cdt: 0.3656
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_172_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_173_p.txt
# density after cdt: 0.3538
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_174_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_175_p.txt
# density after cdt: 0.2982
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_176_p.txt
# density after cdt: 0.3446
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_177_p.txt
# density after cdt: 0.305
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_178_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_179_p.txt
# density after cdt: 0.3667
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_17_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_180_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_181_p.txt
# density after cdt: 0.3833
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_182_p.txt
# density after cdt: 0.3833
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_183_p.txt
# density after cdt: 0.3832
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_184_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_185_p.txt
# density after cdt: 0.3832
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_186_p.txt
# density after cdt: 0.3398
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_187_p.txt
# density after cdt: 0.3794
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_188_p.txt
# density after cdt: 0.3823
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_189_p.txt
# density after cdt: 0.382
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_18_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_190_p.txt
# density after cdt: 0.3659
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_191_p.txt
# density after cdt: 0.3686
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_192_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_193_p.txt
# density after cdt: 0.3081
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_194_p.txt
# density after cdt: 0.2587
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_195_p.txt
# density after cdt: 0.2661
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_196_p.txt
# density after cdt: 0.2342
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_197_p.txt
# density after cdt: 0.2983
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_198_p.txt
# density after cdt: 0.2834
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_199_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_19_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_1_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_200_p.txt
# density after cdt: 0.2586
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_201_p.txt
# density after cdt: 0.3804
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_202_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_203_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_204_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_205_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_206_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_207_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_208_p.txt
# density after cdt: 0.3941
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_209_p.txt
# density after cdt: 0.3803
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_20_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_210_p.txt
# density after cdt: 0.3514
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_211_p.txt
# density after cdt: 0.3804
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_212_p.txt
# density after cdt: 0.3803
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_213_p.txt
# density after cdt: 0.3684
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_214_p.txt
# density after cdt: 0.3936
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_215_p.txt
# density after cdt: 0.2637
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_216_p.txt
# density after cdt: 0.4084
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_217_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_218_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_219_p.txt
# density after cdt: 0.3665
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_21_p.txt
# density after cdt: 0.2437
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_220_p.txt
# density after cdt: 0.3809
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_221_p.txt
# density after cdt: 0.3794
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_222_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_223_p.txt
# density after cdt: 0.3833
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_224_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_225_p.txt
# density after cdt: 0.3803
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_226_p.txt
# density after cdt: 0.3665
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_227_p.txt
# density after cdt: 0.367
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_228_p.txt
# density after cdt: 0.3513
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_229_p.txt
# density after cdt: 0.3937
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_22_p.txt
# density after cdt: 0.3363
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_230_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_231_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_232_p.txt
# density after cdt: 0.3517
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_233_p.txt
# density after cdt: 0.3689
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_234_p.txt
# density after cdt: 0.3804
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_235_p.txt
# density after cdt: 0.3663
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_236_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_237_p.txt
# density after cdt: 0.3803
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_238_p.txt
# density after cdt: 0.3942
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_239_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_23_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_240_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_241_p.txt
# density after cdt: 0.3091
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_242_p.txt
# density after cdt: 0.3388
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_243_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_244_p.txt
# density after cdt: 0.3662
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_245_p.txt
# density after cdt: 0.3508
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_246_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_247_p.txt
# density after cdt: 0.3938
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_248_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_249_p.txt
# density after cdt: 0.3659
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_24_p.txt
# density after cdt: 0.3802
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_250_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_251_p.txt
# density after cdt: 0.3665
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_252_p.txt
# density after cdt: 0.3805
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_253_p.txt
# density after cdt: 0.4076
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_254_p.txt
# density after cdt: 0.3943
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_255_p.txt
# density after cdt: 0.3665
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_256_p.txt
# density after cdt: 0.3668
# pol-->afr
# Loaded testing text file: ./testing_texts/pl_257_p.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\timde\repos\thesis\language_recognition\SDR_Language_recognition.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> test(item_mem, lang_am, N, D)
#
# c:\Users\timde\repos\thesis\language_recognition\SDR_Language_recognition.ipynb Cell 15 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=35'>36</a>     buffer = f.read()
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=36'>37</a> print('Loaded testing text file: ' + str(file_address))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=38'>39</a> item_mem_n, text_hv = window_sum(buffer, item_mem, N, D)
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=39'>40</a> # text_hv = binarize_hv(text_hv, len(buffer))
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=40'>41</a> if (item_mem != item_mem_n):
#
# c:\Users\timde\repos\thesis\language_recognition\SDR_Language_recognition.ipynb Cell 15 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> n_grams = block[0]
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> for j in range(1,N):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a>     n_grams = np.logical_xor(n_grams, block[j])
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> # sum_hv = sum_hv + n_grams
#      <a href='vscode-notebook-cell:/c%3A/Users/timde/repos/thesis/language_recognition/SDR_Language_recognition.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a> sum_hv = np.logical_or(sum_hv,n_grams)
#
# KeyboardInterrupt:

# %%
# other cdt, superimpose part of buffer then cdt then superimpose those
# item_mem2 = np.load('item_mem1.npy', allow_pickle='TRUE').item()
# lang_am2 = np.load('lang_am1.npy', allow_pickle='TRUE').item()

# %%
v = np.array([ 3324, 234234, 24234])
d = np.copy(v)
d[::-1].sort()
print(d)
print(v)
# Out:
# [234234  24234   3324]
# [  3324 234234  24234]
