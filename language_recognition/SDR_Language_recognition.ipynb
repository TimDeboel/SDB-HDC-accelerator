# %%
import numpy as np
import os
# import copy
import random

# %%
###############################################
# Set parameters
###############################################
D = 2000
M = 40   # Number of ones
N = 5     # Sliding window size
m = 5     # Signature size
print("Density: " + str(M/D))
# Out:
# Density: 0.02

# %%
def u_gen_rand_hv(D):

    # Sanity checker
    if (D % 2):
        print("Error - D can't be an odd number")
        return 0

    hv = np.zeros(D, dtype = int)
    indices = np.random.permutation(D)

    hv[indices >= M] = 0
    hv[indices < M] = 1

    return hv

# %%
def u_gen_rand_hv2(D):
  # Sanity checker
    if (D % 2):
        print("Error - D can't be an odd number")
        return 0

    hv = np.zeros(D, dtype=int)
    hv = [1 if random.random() <= M else 0 for x in hv]
    return hv

# %%
def gen_signatures(m):
    if (m < 5):
        print('Small m not implemented yet')
        return 0
    return np.random.permutation(2**m)

# %%
def cos_angle(u,v):
    return np.dot(u,v)/(np.linalg.norm(u)*np.linalg.norm(v))

# %% [markdown]
# # Encoding

# %%
def lookup_item_mem(item_memory, key, D):
    if (item_memory.get(key) is not None):
        value = item_memory[key]
    else:
        value = u_gen_rand_hv(D)
        item_memory[key] = value
        # Create signature
        item_memory['S'+key], item_memory['signatures'] = item_memory['signatures'][-1], item_memory['signatures'][:-1]

    return item_memory, value

# %%
def binarize_hv_sort(v, final_density):
    sort_array = np.copy(v)
    sort_array[::-1].sort()
    cutoff = round(len(v)*final_density)
    threshold = sort_array[cutoff-1]
    # print("Threshold: " + str(threshold))
    # threshold = final_density
    
    for i in range(len(v)):
        if v[i] >= threshold:
            v[i] = 1
        else:
            v[i] = 0
    return v

# %%
def binarize_hv_thr(v, threshold):
    
    for i in range(len(v)):
        if v[i] >= threshold:
            v[i] = 1
        else:
            v[i] = 0
    return v

# %%
def window_sum(buffer, letters_im, N, D, m, thr):
    block = np.zeros((N, D), dtype = int)
    sig_block = np.zeros(N, dtype=int)
    sum_hv = np.zeros(D, dtype = int)
    window_cnt = 0
    for i in range(len(buffer)):
        block = np.roll(block, (0, 1), axis=(1, 0))
        sig_block = np.roll(sig_block, 1)
        letters_im, block[0] = lookup_item_mem(letters_im, buffer[i], D)
        sig_block[0] = letters_im['S'+ buffer[i]]
        
        if i >= (N-1):
            window_hv = np.zeros(D, dtype = int)
            for k in range(0,N):
                xor_tot = 0
                for j in range(0,N):
                    if (j != k):
                        xor_tot = np.bitwise_xor(xor_tot, sig_block[j])
                perm = k + xor_tot    # k: 1->N, then k-1 + XOR's
                window_hv = window_hv + np.roll(block[k],perm)

            thr_window = binarize_hv_thr(window_hv, 2)  # Threshold the window sum
            # print('windowsum', sum(thr_window))
            sum_hv = sum_hv + thr_window    # Bundle the windows together into a text hv
            window_cnt += 1
    
    # THR = 310000
    # thr = 1
    # sum_hv = binarize_hv_sort(sum_hv, 0.1)   # Threshold the text hv
    # sum_hv = binarize_hv_thr(sum_hv, 0.075*window_cnt)   # Threshold the text hv
    # print('cnt: ' + str(window_cnt))
    # print('Density after sum: ' + str(np.sum(sum_hv)/len(sum_hv)))
    # print(np.sum(sum_hv)/len(sum_hv))

    # K = 1
    # thinned_list = []
    # for k in range(1,K+1):
    #     thinned_list.append(np.logical_and(sum_hv, np.roll(sum_hv,k)))
    # thinned_sum = np.array([1 if x >= 1 else 0 for x in sum(thinned_list)])

    # print('density after cdt: ' + str(np.sum(thinned_sum)/len(thinned_sum)))       
    return letters_im, sum_hv, window_cnt

# %%
def binarize_language_hv(lang_am, thr):
    # lang_labels = ['afr', 'bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    lang_labels = ['bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    # lang_labels = ['afr', 'bul']
    lang_am_new = dict()
    for j in lang_labels:
        v = lang_am[j].copy()
        lang_am_new[j] = binarize_hv_sort(v, thr)
    return lang_am_new

# %% [markdown]
# # Training

# %%
def build_memories(N, D, m):
    item_mem = dict()
    lang_am = dict()
    lang_am_full = dict()
    # lang_labels = ['afr', 'bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    lang_labels = ['bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    # lang_labels = ['bul','ces', 'dan','deu','eng','ell','spa']
    # lang_labels = ['afr', 'bul', 'ces', 'dan']
    item_mem['signatures'] = gen_signatures(m)

    for i in lang_labels:
        print('Reading file: ' + i)
        file_address = './training_texts/' + i + '.txt'
        with open(file_address) as f:
            buffer = f.read()

        THR = 310000
        # THR = 0.2*len(buffer)
        item_mem, lang_hv, window_cnt = window_sum(buffer, item_mem, N, D, m, THR)
        lang_am_full[i] = lang_hv.copy()
        # lang_am[i] = binarize_hv_thr(lang_hv, 0.024*window_cnt)
        lang_am[i] = binarize_hv_sort(lang_hv, 0.40)
        # lang_am[i] = lang_hv
        print('Density' + i + ': ' + str(np.sum(lang_am[i])/D))

        
    return item_mem, lang_am, lang_am_full

# %%
def test(item_mem, lang_am, N, D, m):
    total = 0
    correct = 0
    # lang_labels = ['afr', 'bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    lang_labels = ['bul', 'ces', 'dan', 'nld', 'deu', 'eng', 'est', 'fin', 'fra', 'ell', 'hun', 'ita', 'lav', 'lit', 'pol', 'por', 'ron', 'slk', 'slv', 'spa', 'swe']
    lang_map = dict()
    lang_map['af'] = 'afr'
    lang_map['bg'] = 'bul'
    lang_map['cs'] = 'ces'
    lang_map['da'] = 'dan'
    lang_map['nl'] = 'nld'
    lang_map['de'] = 'deu'
    lang_map['en'] = 'eng'
    lang_map['et'] = 'est'
    lang_map['fi'] = 'fin'
    lang_map['fr'] = 'fra'
    lang_map['el'] = 'ell'
    lang_map['hu'] = 'hun'
    lang_map['it'] = 'ita'
    lang_map['lv'] = 'lav'
    lang_map['lt'] = 'lit'
    lang_map['pl'] = 'pol'
    lang_map['pt'] = 'por'
    lang_map['ro'] = 'ron'
    lang_map['sk'] = 'slk'
    lang_map['sl'] = 'slv'
    lang_map['es'] = 'spa'
    lang_map['sv'] = 'swe'

    for file in os.listdir('./testing_texts/'):
        if file.endswith('.txt'):
            actual_label = file[0:2]
            predict_lang = ''

            file_address = './testing_texts/' + file
            with open(file_address) as f:
                buffer = f.read()
            print('Loaded testing text file: ' + str(file_address))
            bufferlength = len(buffer)
            # print("Buffer length: " + str(bufferlength))
            test_thr = 0.3
            # print("THR value: " + str(test_thr))

            item_mem_n, text_hv, window_cnt = window_sum(buffer, item_mem, N, D, m, test_thr)
            # text_hv = binarize_hv_thr(text_hv, 0.022*window_cnt)
            text_hv = binarize_hv_thr(text_hv, 0.001*window_cnt)
            # text_hv = binarize_hv_sort(text_hv, 0.06)
            print('Density: '+ str(np.sum(text_hv)/D))
            if (item_mem != item_mem_n):
                print('\n>>>> NEW UNSEEN ITEM IN TEST FILE <<<<\n')
                exit()
            else:
                max_angle = -1
                # max_angle = 10000
                for j in range(len(lang_labels)):
                    if (lang_labels[j] in lang_am.keys()):
                        # angle = cos_angle(lang_am[lang_labels[j]], text_hv)     # Cosine similarity
                        angle = np.sum(np.logical_and(lang_am[lang_labels[j]], text_hv))       # Overlap
                        if (angle > max_angle):
                        # if (angle < max_angle):
                            max_angle = angle
                            predict_lang = lang_labels[j]
                
                if (predict_lang == lang_map[actual_label]):
                    correct += 1
                else:
                    print(str(lang_map[actual_label]) + '-->' + predict_lang)
                total += 1
                print('Accuracy: ' + str(correct / total))
    return correct / total

# %%
item_mem, lang_am, lang_am_full = build_memories(N,D,m)
# Out:
# Reading file: bul
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 item_mem, lang_am, lang_am_full = build_memories(N,D,m)
#
# Cell In[29], line 19, in build_memories(N, D, m)
#      17 THR = 310000
#      18 # THR = 0.2*len(buffer)
# ---> 19 item_mem, lang_hv, window_cnt = window_sum(buffer, item_mem, N, D, m, THR)
#      20 lang_am_full[i] = lang_hv.copy()
#      21 # lang_am[i] = binarize_hv_thr(lang_hv, 0.024*window_cnt)
#
# Cell In[27], line 20, in window_sum(buffer, letters_im, N, D, m, thr)
#      18             xor_tot = np.bitwise_xor(xor_tot, sig_block[j])
#      19     perm = k + xor_tot    # k: 1->N, then k-1 + XOR's
# ---> 20     window_hv = window_hv + np.roll(block[k],perm)
#      22 thr_window = binarize_hv_thr(window_hv, 2)  # Threshold the window sum
#      23 # print('windowsum', sum(thr_window))
#
# KeyboardInterrupt:

# %%
# np.save('item_mem_2k_2d_5w.npy', item_mem)
# np.save('lang_am_2k_2d.npy', lang_am)
# np.save('lang_am_full_2k_2d_5w.npy', lang_am_full)
# np.save('lang_am_all_500_full.npy', lang_am_full)
# item_mem = np.load('new_data/item_mem_2k_2d_5w.npy', allow_pickle='TRUE').item()
# lang_am_full = np.load('new_data/lang_am_full_2k_2d_5w.npy', allow_pickle='TRUE').item()

# lang_am = np.copy(lang_am2)
lang_am = binarize_language_hv(lang_am_full, 0.50)
# item_mem = dict()
# lang_am = dict()

# %%
test(item_mem, lang_am, N, D, m)
# Out:
# Loaded testing text file: ./testing_texts/bg_0_p.txt
# Density: 0.24
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_100_p.txt
# Density: 0.3435
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_101_p.txt
# Density: 0.613
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_102_p.txt
# Density: 0.4165
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_103_p.txt
# Density: 0.3755
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_104_p.txt
# Density: 0.485
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_105_p.txt
# Density: 0.284
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_106_p.txt
# Density: 0.5025
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_107_p.txt
# Density: 0.3215
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_108_p.txt
# Density: 0.5195
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_109_p.txt
# Density: 0.4605
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_10_p.txt
# Density: 0.214
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_110_p.txt
# Density: 0.26
# Accuracy: 1.0
# Loaded testing text file: ./testing_texts/bg_111_p.txt
# Density: 0.4405
# bul-->pol
# Accuracy: 0.9285714285714286
# Loaded testing text file: ./testing_texts/bg_112_p.txt
# Density: 0.3295
# Accuracy: 0.9333333333333333
# Loaded testing text file: ./testing_texts/bg_113_p.txt
# Density: 0.657
# Accuracy: 0.9375
# Loaded testing text file: ./testing_texts/bg_114_p.txt
# Density: 0.1975
# bul-->slk
# Accuracy: 0.8823529411764706
# Loaded testing text file: ./testing_texts/bg_115_p.txt
# Density: 0.47
# Accuracy: 0.8888888888888888
# Loaded testing text file: ./testing_texts/bg_116_p.txt
# Density: 0.2345
# Accuracy: 0.8947368421052632
# Loaded testing text file: ./testing_texts/bg_117_p.txt
# Density: 0.404
# Accuracy: 0.9
# Loaded testing text file: ./testing_texts/bg_118_p.txt
# Density: 0.163
# Accuracy: 0.9047619047619048
# Loaded testing text file: ./testing_texts/bg_119_p.txt
# Density: 0.39
# Accuracy: 0.9090909090909091
# Loaded testing text file: ./testing_texts/bg_11_p.txt
# Density: 0.63
# Accuracy: 0.9130434782608695
# Loaded testing text file: ./testing_texts/bg_120_p.txt
# Density: 0.4395
# Accuracy: 0.9166666666666666
# Loaded testing text file: ./testing_texts/bg_121_p.txt
# Density: 0.1835
# bul-->eng
# Accuracy: 0.88
# Loaded testing text file: ./testing_texts/bg_122_p.txt
# Density: 0.3935
# Accuracy: 0.8846153846153846
# Loaded testing text file: ./testing_texts/bg_123_p.txt
# Density: 0.228
# Accuracy: 0.8888888888888888
# Loaded testing text file: ./testing_texts/bg_124_p.txt
# Density: 0.349
# bul-->fin
# Accuracy: 0.8571428571428571
# Loaded testing text file: ./testing_texts/bg_125_p.txt
# Density: 0.6225
# Accuracy: 0.8620689655172413
# Loaded testing text file: ./testing_texts/bg_126_p.txt
# Density: 0.5005
# Accuracy: 0.8666666666666667
# Loaded testing text file: ./testing_texts/bg_127_p.txt
# Density: 0.4785
# Accuracy: 0.8709677419354839
# Loaded testing text file: ./testing_texts/bg_128_p.txt
# Density: 0.3975
# Accuracy: 0.875
# Loaded testing text file: ./testing_texts/bg_129_p.txt
# Density: 0.5045
# Accuracy: 0.8787878787878788
# Loaded testing text file: ./testing_texts/bg_12_p.txt
# Density: 0.3135
# bul-->ces
# Accuracy: 0.8529411764705882
# Loaded testing text file: ./testing_texts/bg_130_p.txt
# Density: 0.3265
# Accuracy: 0.8571428571428571
# Loaded testing text file: ./testing_texts/bg_131_p.txt
# Density: 0.568
# Accuracy: 0.8611111111111112
# Loaded testing text file: ./testing_texts/bg_132_p.txt
# Density: 0.5995
# Accuracy: 0.8648648648648649
# Loaded testing text file: ./testing_texts/bg_133_p.txt
# Density: 0.6065
# Accuracy: 0.868421052631579
# Loaded testing text file: ./testing_texts/bg_134_p.txt
# Density: 0.174
# Accuracy: 0.8717948717948718
# Loaded testing text file: ./testing_texts/bg_135_p.txt
# Density: 0.3485
# Accuracy: 0.875
# Loaded testing text file: ./testing_texts/bg_136_p.txt
# Density: 0.2725
# Accuracy: 0.8780487804878049
# Loaded testing text file: ./testing_texts/bg_137_p.txt
# Density: 0.407
# Accuracy: 0.8809523809523809
# Loaded testing text file: ./testing_texts/bg_138_p.txt
# Density: 0.39
# Accuracy: 0.8837209302325582
# Loaded testing text file: ./testing_texts/bg_139_p.txt
# Density: 0.246
# Accuracy: 0.8863636363636364
# Loaded testing text file: ./testing_texts/bg_13_p.txt
# Density: 0.378
# Accuracy: 0.8888888888888888
# Loaded testing text file: ./testing_texts/bg_140_p.txt
# Density: 0.116
# bul-->ita
# Accuracy: 0.8695652173913043
# Loaded testing text file: ./testing_texts/bg_141_p.txt
# Density: 0.106
# bul-->ita
# Accuracy: 0.851063829787234
# Loaded testing text file: ./testing_texts/bg_142_p.txt
# Density: 0.406
# Accuracy: 0.8541666666666666
# Loaded testing text file: ./testing_texts/bg_143_p.txt
# Density: 0.3075
# bul-->slk
# Accuracy: 0.8367346938775511
# Loaded testing text file: ./testing_texts/bg_144_p.txt
# Density: 0.3295
# Accuracy: 0.84
# Loaded testing text file: ./testing_texts/bg_145_p.txt
# Density: 0.3275
# Accuracy: 0.8431372549019608
# Loaded testing text file: ./testing_texts/bg_146_p.txt
# Density: 0.325
# Accuracy: 0.8461538461538461
# Loaded testing text file: ./testing_texts/bg_147_p.txt
# Density: 0.3175
# Accuracy: 0.8490566037735849
# Loaded testing text file: ./testing_texts/bg_148_p.txt
# Density: 0.426
# Accuracy: 0.8518518518518519
# Loaded testing text file: ./testing_texts/bg_149_p.txt
# Density: 0.266
# Accuracy: 0.8545454545454545
# Loaded testing text file: ./testing_texts/bg_14_p.txt
# Density: 0.611
# Accuracy: 0.8571428571428571
# Loaded testing text file: ./testing_texts/bg_150_p.txt
# Density: 0.3305
# bul-->lav
# Accuracy: 0.8421052631578947
# Loaded testing text file: ./testing_texts/bg_151_p.txt
# Density: 0.389
# bul-->lit
# Accuracy: 0.8275862068965517
# Loaded testing text file: ./testing_texts/bg_152_p.txt
# Density: 0.1095
# bul-->fin
# Accuracy: 0.8135593220338984
# Loaded testing text file: ./testing_texts/bg_153_p.txt
# Density: 0.381
# Accuracy: 0.8166666666666667
# Loaded testing text file: ./testing_texts/bg_154_p.txt
# Density: 0.2475
# Accuracy: 0.819672131147541
# Loaded testing text file: ./testing_texts/bg_155_p.txt
# Density: 0.4065
# Accuracy: 0.8225806451612904
# Loaded testing text file: ./testing_texts/bg_156_p.txt
# Density: 0.27
# Accuracy: 0.8253968253968254
# Loaded testing text file: ./testing_texts/bg_157_p.txt
# Density: 0.2905
# Accuracy: 0.828125
# Loaded testing text file: ./testing_texts/bg_158_p.txt
# Density: 0.319
# Accuracy: 0.8307692307692308
# Loaded testing text file: ./testing_texts/bg_159_p.txt
# Density: 0.3685
# Accuracy: 0.8333333333333334
# Loaded testing text file: ./testing_texts/bg_15_p.txt
# Density: 0.5815
# Accuracy: 0.835820895522388
# Loaded testing text file: ./testing_texts/bg_160_p.txt
# Density: 0.464
# Accuracy: 0.8382352941176471
# Loaded testing text file: ./testing_texts/bg_161_p.txt
# Density: 0.452
# Accuracy: 0.8405797101449275
# Loaded testing text file: ./testing_texts/bg_162_p.txt
# Density: 0.5075
# Accuracy: 0.8428571428571429
# Loaded testing text file: ./testing_texts/bg_163_p.txt
# Density: 0.66
# Accuracy: 0.8450704225352113
# Loaded testing text file: ./testing_texts/bg_164_p.txt
# Density: 0.2145
# Accuracy: 0.8472222222222222
# Loaded testing text file: ./testing_texts/bg_165_p.txt
# Density: 0.351
# Accuracy: 0.8493150684931506
# Loaded testing text file: ./testing_texts/bg_166_p.txt
# Density: 0.5205
# Accuracy: 0.8513513513513513
# Loaded testing text file: ./testing_texts/bg_167_p.txt
# Density: 0.2835
# Accuracy: 0.8533333333333334
# Loaded testing text file: ./testing_texts/bg_168_p.txt
# Density: 0.33
# Accuracy: 0.8552631578947368
# Loaded testing text file: ./testing_texts/bg_169_p.txt
# Density: 0.485
# Accuracy: 0.8571428571428571
# Loaded testing text file: ./testing_texts/bg_16_p.txt
# Density: 0.4685
# Accuracy: 0.8589743589743589
# Loaded testing text file: ./testing_texts/bg_170_p.txt
# Density: 0.5455
# Accuracy: 0.8607594936708861
# Loaded testing text file: ./testing_texts/bg_171_p.txt
# Density: 0.5855
# Accuracy: 0.8625
# Loaded testing text file: ./testing_texts/bg_172_p.txt
# Density: 0.231
# bul-->pol
# Accuracy: 0.8518518518518519
# Loaded testing text file: ./testing_texts/bg_173_p.txt
# Density: 0.584
# Accuracy: 0.8536585365853658
# Loaded testing text file: ./testing_texts/bg_174_p.txt
# Density: 0.082
# Accuracy: 0.8554216867469879
# Loaded testing text file: ./testing_texts/bg_175_p.txt
# Density: 0.4835
# Accuracy: 0.8571428571428571
# Loaded testing text file: ./testing_texts/bg_176_p.txt
# Density: 0.3975
# Accuracy: 0.8588235294117647
# Loaded testing text file: ./testing_texts/bg_177_p.txt
# Density: 0.445
# bul-->swe
# Accuracy: 0.8488372093023255
# Loaded testing text file: ./testing_texts/bg_178_p.txt
# Density: 0.281
# Accuracy: 0.8505747126436781
# Loaded testing text file: ./testing_texts/bg_179_p.txt
# Density: 0.394
# Accuracy: 0.8522727272727273
# Loaded testing text file: ./testing_texts/bg_17_p.txt
# Density: 0.562
# Accuracy: 0.8539325842696629
# Loaded testing text file: ./testing_texts/bg_180_p.txt
# Density: 0.431
# Accuracy: 0.8555555555555555
# Loaded testing text file: ./testing_texts/bg_181_p.txt
# Density: 0.2385
# Accuracy: 0.8571428571428571
# Loaded testing text file: ./testing_texts/bg_182_p.txt
# Density: 0.3125
# Accuracy: 0.8586956521739131
# Loaded testing text file: ./testing_texts/bg_183_p.txt
# Density: 0.4035
# Accuracy: 0.8602150537634409
# Loaded testing text file: ./testing_texts/bg_184_p.txt
# Density: 0.5325
# Accuracy: 0.8617021276595744
# Loaded testing text file: ./testing_texts/bg_185_p.txt
# Density: 0.234
# bul-->slv
# Accuracy: 0.8526315789473684
# Loaded testing text file: ./testing_texts/bg_186_p.txt
# Density: 0.31
# Accuracy: 0.8541666666666666
# Loaded testing text file: ./testing_texts/bg_187_p.txt
# Density: 0.3125
# Accuracy: 0.8556701030927835
# Loaded testing text file: ./testing_texts/bg_188_p.txt
# Density: 0.4675
# Accuracy: 0.8571428571428571
# Loaded testing text file: ./testing_texts/bg_189_p.txt
# Density: 0.257
# bul-->ces
# Accuracy: 0.8484848484848485
# Loaded testing text file: ./testing_texts/bg_18_p.txt
# Density: 0.678
# Accuracy: 0.85
# Loaded testing text file: ./testing_texts/bg_190_p.txt
# Density: 0.4165
# bul-->slk
# Accuracy: 0.8415841584158416
# Loaded testing text file: ./testing_texts/bg_191_p.txt
# Density: 0.6295
# Accuracy: 0.8431372549019608
# Loaded testing text file: ./testing_texts/bg_192_p.txt
# Density: 0.2725
# Accuracy: 0.8446601941747572
# Loaded testing text file: ./testing_texts/bg_193_p.txt
# Density: 0.5445
# Accuracy: 0.8461538461538461
# Loaded testing text file: ./testing_texts/bg_194_p.txt
# Density: 0.409
# Accuracy: 0.8476190476190476
# Loaded testing text file: ./testing_texts/bg_195_p.txt
# Density: 0.7065
# Accuracy: 0.8490566037735849
# Loaded testing text file: ./testing_texts/bg_196_p.txt
# Density: 0.502
# Accuracy: 0.8504672897196262
# Loaded testing text file: ./testing_texts/bg_197_p.txt
# Density: 0.2745
# bul-->ces
# Accuracy: 0.8425925925925926
# Loaded testing text file: ./testing_texts/bg_198_p.txt
# Density: 0.2695
# bul-->slk
# Accuracy: 0.8348623853211009
# Loaded testing text file: ./testing_texts/bg_199_p.txt
# Density: 0.324
# bul-->slk
# Accuracy: 0.8272727272727273
# Loaded testing text file: ./testing_texts/bg_19_p.txt
# Density: 0.436
# bul-->slk
# Accuracy: 0.8198198198198198
# Loaded testing text file: ./testing_texts/bg_1_p.txt
# Density: 0.4435
# Accuracy: 0.8214285714285714
# Loaded testing text file: ./testing_texts/bg_200_p.txt
# Density: 0.174
# bul-->slk
# Accuracy: 0.8141592920353983
# Loaded testing text file: ./testing_texts/bg_201_p.txt
# Density: 0.34
# Accuracy: 0.8157894736842105
# Loaded testing text file: ./testing_texts/bg_202_p.txt
# Density: 0.076
# Accuracy: 0.8173913043478261
# Loaded testing text file: ./testing_texts/bg_203_p.txt
# Density: 0.2075
# bul-->hun
# Accuracy: 0.8103448275862069
# Loaded testing text file: ./testing_texts/bg_204_p.txt
# Density: 0.316
# Accuracy: 0.811965811965812
# Loaded testing text file: ./testing_texts/bg_205_p.txt
# Density: 0.3735
# Accuracy: 0.8135593220338984
# Loaded testing text file: ./testing_texts/bg_206_p.txt
# Density: 0.4585
# bul-->slk
# Accuracy: 0.8067226890756303
# Loaded testing text file: ./testing_texts/bg_207_p.txt
# Density: 0.3315
# bul-->est
# Accuracy: 0.8
# Loaded testing text file: ./testing_texts/bg_208_p.txt
# Density: 0.5085
# bul-->ita
# Accuracy: 0.7933884297520661
# Loaded testing text file: ./testing_texts/bg_209_p.txt
# Density: 0.3075
# bul-->slk
# Accuracy: 0.7868852459016393
# Loaded testing text file: ./testing_texts/bg_20_p.txt
# Density: 0.147
# bul-->nld
# Accuracy: 0.7804878048780488
# Loaded testing text file: ./testing_texts/bg_210_p.txt
# Density: 0.564
# Accuracy: 0.782258064516129
# Loaded testing text file: ./testing_texts/bg_211_p.txt
# Density: 0.5675
# Accuracy: 0.784
# Loaded testing text file: ./testing_texts/bg_212_p.txt
# Density: 0.446
# Accuracy: 0.7857142857142857
# Loaded testing text file: ./testing_texts/bg_213_p.txt
# Density: 0.388
# bul-->hun
# Accuracy: 0.7795275590551181
# Loaded testing text file: ./testing_texts/bg_214_p.txt
# Density: 0.086
# bul-->slk
# Accuracy: 0.7734375
# Loaded testing text file: ./testing_texts/bg_215_p.txt
# Density: 0.556
# Accuracy: 0.7751937984496124
# Loaded testing text file: ./testing_texts/bg_216_p.txt
# Density: 0.7535
# Accuracy: 0.7769230769230769
# Loaded testing text file: ./testing_texts/bg_217_p.txt
# Density: 0.403
# Accuracy: 0.7786259541984732
# Loaded testing text file: ./testing_texts/bg_218_p.txt
# Density: 0.3535
# Accuracy: 0.7803030303030303
# Loaded testing text file: ./testing_texts/bg_219_p.txt
# Density: 0.183
# bul-->slv
# Accuracy: 0.7744360902255639
# Loaded testing text file: ./testing_texts/bg_21_p.txt
# Density: 0.219
# bul-->slv
# Accuracy: 0.7686567164179104
# Loaded testing text file: ./testing_texts/bg_220_p.txt
# Density: 0.4445
# Accuracy: 0.7703703703703704
# Loaded testing text file: ./testing_texts/bg_221_p.txt
# Density: 0.151
# bul-->ell
# Accuracy: 0.7647058823529411
# Loaded testing text file: ./testing_texts/bg_222_p.txt
# Density: 0.5915
# Accuracy: 0.7664233576642335
# Loaded testing text file: ./testing_texts/bg_223_p.txt
# Density: 0.439
# Accuracy: 0.7681159420289855
# Loaded testing text file: ./testing_texts/bg_224_p.txt
# Density: 0.515
# Accuracy: 0.7697841726618705
# Loaded testing text file: ./testing_texts/bg_225_p.txt
# Density: 0.483
# Accuracy: 0.7714285714285715
# Loaded testing text file: ./testing_texts/bg_226_p.txt
# Density: 0.2815
# bul-->est
# Accuracy: 0.7659574468085106
# Loaded testing text file: ./testing_texts/bg_227_p.txt
# Density: 0.437
# Accuracy: 0.7676056338028169
# Loaded testing text file: ./testing_texts/bg_228_p.txt
# Density: 0.401
# bul-->slk
# Accuracy: 0.7622377622377622
# Loaded testing text file: ./testing_texts/bg_229_p.txt
# Density: 0.535
# Accuracy: 0.7638888888888888
# Loaded testing text file: ./testing_texts/bg_22_p.txt
# Density: 0.7485
# Accuracy: 0.7655172413793103
# Loaded testing text file: ./testing_texts/bg_230_p.txt
# Density: 0.4685
# Accuracy: 0.7671232876712328
# Loaded testing text file: ./testing_texts/bg_231_p.txt
# Density: 0.2835
# Accuracy: 0.7687074829931972
# Loaded testing text file: ./testing_texts/bg_232_p.txt
# Density: 0.4485
# Accuracy: 0.7702702702702703
# Loaded testing text file: ./testing_texts/bg_233_p.txt
# Density: 0.276
# Accuracy: 0.7718120805369127
# Loaded testing text file: ./testing_texts/bg_234_p.txt
# Density: 0.174
# Accuracy: 0.7733333333333333
# Loaded testing text file: ./testing_texts/bg_235_p.txt
# Density: 0.5525
# Accuracy: 0.7748344370860927
# Loaded testing text file: ./testing_texts/bg_236_p.txt
# Density: 0.3695
# Accuracy: 0.7763157894736842
# Loaded testing text file: ./testing_texts/bg_237_p.txt
# Density: 0.3625
# Accuracy: 0.7777777777777778
# Loaded testing text file: ./testing_texts/bg_238_p.txt
# Density: 0.378
# bul-->fin
# Accuracy: 0.7727272727272727
# Loaded testing text file: ./testing_texts/bg_239_p.txt
# Density: 0.3755
# Accuracy: 0.7741935483870968
# Loaded testing text file: ./testing_texts/bg_23_p.txt
# Density: 0.4825
# Accuracy: 0.7756410256410257
# Loaded testing text file: ./testing_texts/bg_240_p.txt
# Density: 0.279
# bul-->slk
# Accuracy: 0.7707006369426752
# Loaded testing text file: ./testing_texts/bg_241_p.txt
# Density: 0.096
# bul-->hun
# Accuracy: 0.7658227848101266
# Loaded testing text file: ./testing_texts/bg_242_p.txt
# Density: 0.6655
# Accuracy: 0.7672955974842768
# Loaded testing text file: ./testing_texts/bg_243_p.txt
# Density: 0.3075
# Accuracy: 0.76875
# Loaded testing text file: ./testing_texts/bg_244_p.txt
# Density: 0.4895
# Accuracy: 0.7701863354037267
# Loaded testing text file: ./testing_texts/bg_245_p.txt
# Density: 0.6875
# Accuracy: 0.7716049382716049
# Loaded testing text file: ./testing_texts/bg_246_p.txt
# Density: 0.3835
# Accuracy: 0.7730061349693251
# Loaded testing text file: ./testing_texts/bg_247_p.txt
# Density: 0.3
# Accuracy: 0.774390243902439
# Loaded testing text file: ./testing_texts/bg_248_p.txt
# Density: 0.5345
# Accuracy: 0.7757575757575758
# Loaded testing text file: ./testing_texts/bg_249_p.txt
# Density: 0.5495
# Accuracy: 0.7771084337349398
# Loaded testing text file: ./testing_texts/bg_24_p.txt
# Density: 0.381
# Accuracy: 0.7784431137724551
# Loaded testing text file: ./testing_texts/bg_250_p.txt
# Density: 0.1355
# bul-->ell
# Accuracy: 0.7738095238095238
# Loaded testing text file: ./testing_texts/bg_251_p.txt
# Density: 0.517
# Accuracy: 0.7751479289940828
# Loaded testing text file: ./testing_texts/bg_252_p.txt
# Density: 0.306
# Accuracy: 0.7764705882352941
# Loaded testing text file: ./testing_texts/bg_253_p.txt
# Density: 0.264
# bul-->hun
# Accuracy: 0.7719298245614035
# Loaded testing text file: ./testing_texts/bg_254_p.txt
# Density: 0.402
# Accuracy: 0.7732558139534884
# Loaded testing text file: ./testing_texts/bg_255_p.txt
# Density: 0.658
# Accuracy: 0.7745664739884393
# Loaded testing text file: ./testing_texts/bg_256_p.txt
# Density: 0.43
# Accuracy: 0.7758620689655172
# Loaded testing text file: ./testing_texts/bg_257_p.txt
# Density: 0.139
# bul-->por
# Accuracy: 0.7714285714285715
# Loaded testing text file: ./testing_texts/bg_258_p.txt
# Density: 0.546
# bul-->slv
# Accuracy: 0.7670454545454546
# Loaded testing text file: ./testing_texts/bg_259_p.txt
# Density: 0.4735
# Accuracy: 0.768361581920904
# Loaded testing text file: ./testing_texts/bg_25_p.txt
# Density: 0.365
# bul-->ces
# Accuracy: 0.7640449438202247
# Loaded testing text file: ./testing_texts/bg_260_p.txt
# Density: 0.38
# Accuracy: 0.7653631284916201
# Loaded testing text file: ./testing_texts/bg_261_p.txt
# Density: 0.4505
# Accuracy: 0.7666666666666667
# Loaded testing text file: ./testing_texts/bg_262_p.txt
# Density: 0.14
# Accuracy: 0.7679558011049724
# Loaded testing text file: ./testing_texts/bg_263_p.txt
# Density: 0.143
# Accuracy: 0.7692307692307693
# Loaded testing text file: ./testing_texts/bg_264_p.txt
# Density: 0.4955
# Accuracy: 0.7704918032786885
# Loaded testing text file: ./testing_texts/bg_265_p.txt
# Density: 0.18
# Accuracy: 0.7717391304347826
# Loaded testing text file: ./testing_texts/bg_266_p.txt
# Density: 0.447
# Accuracy: 0.772972972972973
# Loaded testing text file: ./testing_texts/bg_267_p.txt
# Density: 0.4725
# Accuracy: 0.7741935483870968
# Loaded testing text file: ./testing_texts/bg_268_p.txt
# Density: 0.7955
# Accuracy: 0.7754010695187166
# Loaded testing text file: ./testing_texts/bg_269_p.txt
# Density: 0.5865
# bul-->slk
# Accuracy: 0.7712765957446809
# Loaded testing text file: ./testing_texts/bg_26_p.txt
# Density: 0.366
# Accuracy: 0.7724867724867724
# Loaded testing text file: ./testing_texts/bg_270_p.txt
# Density: 0.494
# Accuracy: 0.7736842105263158
# Loaded testing text file: ./testing_texts/bg_271_p.txt
# Density: 0.414
# Accuracy: 0.774869109947644
# Loaded testing text file: ./testing_texts/bg_272_p.txt
# Density: 0.345
# Accuracy: 0.7760416666666666
# Loaded testing text file: ./testing_texts/bg_273_p.txt
# Density: 0.2235
# Accuracy: 0.7772020725388601
# Loaded testing text file: ./testing_texts/bg_274_p.txt
# Density: 0.28
# Accuracy: 0.7783505154639175
# Loaded testing text file: ./testing_texts/bg_275_p.txt
# Density: 0.3105
# Accuracy: 0.7794871794871795
# Loaded testing text file: ./testing_texts/bg_276_p.txt
# Density: 0.385
# Accuracy: 0.7806122448979592
# Loaded testing text file: ./testing_texts/bg_277_p.txt
# Density: 0.631
# Accuracy: 0.7817258883248731
# Loaded testing text file: ./testing_texts/bg_278_p.txt
# Density: 0.4515
# Accuracy: 0.7828282828282829
# Loaded testing text file: ./testing_texts/bg_279_p.txt
# Density: 0.168
# bul-->ell
# Accuracy: 0.7788944723618091
# Loaded testing text file: ./testing_texts/bg_27_p.txt
# Density: 0.6205
# Accuracy: 0.78
# Loaded testing text file: ./testing_texts/bg_280_p.txt
# Density: 0.4485
# Accuracy: 0.7810945273631841
# Loaded testing text file: ./testing_texts/bg_281_p.txt
# Density: 0.239
# bul-->nld
# Accuracy: 0.7772277227722773
# Loaded testing text file: ./testing_texts/bg_282_p.txt
# Density: 0.106
# Accuracy: 0.7783251231527094
# Loaded testing text file: ./testing_texts/bg_283_p.txt
# Density: 0.1535
# Accuracy: 0.7794117647058824
# Loaded testing text file: ./testing_texts/bg_284_p.txt
# Density: 0.278
# Accuracy: 0.7804878048780488
# Loaded testing text file: ./testing_texts/bg_285_p.txt
# Density: 0.651
# Accuracy: 0.7815533980582524
# Loaded testing text file: ./testing_texts/bg_286_p.txt
# Density: 0.2115
# Accuracy: 0.782608695652174
# Loaded testing text file: ./testing_texts/bg_287_p.txt
# Density: 0.368
# Accuracy: 0.7836538461538461
# Loaded testing text file: ./testing_texts/bg_288_p.txt
# Density: 0.31
# Accuracy: 0.784688995215311
# Loaded testing text file: ./testing_texts/bg_289_p.txt
# Density: 0.4055
# Accuracy: 0.7857142857142857
# Loaded testing text file: ./testing_texts/bg_28_p.txt
# Density: 0.5665
# Accuracy: 0.7867298578199052
# Loaded testing text file: ./testing_texts/bg_290_p.txt
# Density: 0.1935
# Accuracy: 0.7877358490566038
# Loaded testing text file: ./testing_texts/bg_291_p.txt
# Density: 0.292
# Accuracy: 0.7887323943661971
# Loaded testing text file: ./testing_texts/bg_292_p.txt
# Density: 0.39
# bul-->slv
# Accuracy: 0.7850467289719626
# Loaded testing text file: ./testing_texts/bg_293_p.txt
# Density: 0.3835
# bul-->ces
# Accuracy: 0.7813953488372093
# Loaded testing text file: ./testing_texts/bg_294_p.txt
# Density: 0.571
# Accuracy: 0.7824074074074074
# Loaded testing text file: ./testing_texts/bg_295_p.txt
# Density: 0.5775
# Accuracy: 0.783410138248848
# Loaded testing text file: ./testing_texts/bg_296_p.txt
# Density: 0.3245
# bul-->ell
# Accuracy: 0.7798165137614679
# Loaded testing text file: ./testing_texts/bg_297_p.txt
# Density: 0.136
# bul-->slv
# Accuracy: 0.776255707762557
# Loaded testing text file: ./testing_texts/bg_298_p.txt
# Density: 0.259
# Accuracy: 0.7772727272727272
# Loaded testing text file: ./testing_texts/bg_299_p.txt
# Density: 0.169
# bul-->lit
# Accuracy: 0.7737556561085973
# Loaded testing text file: ./testing_texts/bg_29_p.txt
# Density: 0.439
# bul-->lav
# Accuracy: 0.7702702702702703
# Loaded testing text file: ./testing_texts/bg_2_p.txt
# Density: 0.2585
# bul-->slk
# Accuracy: 0.7668161434977578
# Loaded testing text file: ./testing_texts/bg_300_p.txt
# Density: 0.3905
# Accuracy: 0.7678571428571429
# Loaded testing text file: ./testing_texts/bg_301_p.txt
# Density: 0.404
# Accuracy: 0.7688888888888888
# Loaded testing text file: ./testing_texts/bg_302_p.txt
# Density: 0.46
# Accuracy: 0.7699115044247787
# Loaded testing text file: ./testing_texts/bg_303_p.txt
# Density: 0.62
# Accuracy: 0.7709251101321586
# Loaded testing text file: ./testing_texts/bg_304_p.txt
# Density: 0.448
# Accuracy: 0.7719298245614035
# Loaded testing text file: ./testing_texts/bg_305_p.txt
# Density: 0.5415
# Accuracy: 0.7729257641921398
# Loaded testing text file: ./testing_texts/bg_306_p.txt
# Density: 0.2155
# Accuracy: 0.7739130434782608
# Loaded testing text file: ./testing_texts/bg_307_p.txt
# Density: 0.2395
# Accuracy: 0.7748917748917749
# Loaded testing text file: ./testing_texts/bg_308_p.txt
# Density: 0.397
# Accuracy: 0.7758620689655172
# Loaded testing text file: ./testing_texts/bg_309_p.txt
# Density: 0.356
# Accuracy: 0.776824034334764
# Loaded testing text file: ./testing_texts/bg_30_p.txt
# Density: 0.4765
# Accuracy: 0.7777777777777778
# Loaded testing text file: ./testing_texts/bg_310_p.txt
# Density: 0.473
# Accuracy: 0.7787234042553192
# Loaded testing text file: ./testing_texts/bg_311_p.txt
# Density: 0.2115
# Accuracy: 0.7796610169491526
# Loaded testing text file: ./testing_texts/bg_312_p.txt
# Density: 0.378
# Accuracy: 0.7805907172995781
# Loaded testing text file: ./testing_texts/bg_313_p.txt
# Density: 0.2115
# Accuracy: 0.7815126050420168
# Loaded testing text file: ./testing_texts/bg_314_p.txt
# Density: 0.3765
# Accuracy: 0.7824267782426778
# Loaded testing text file: ./testing_texts/bg_315_p.txt
# Density: 0.103
# Accuracy: 0.7833333333333333
# Loaded testing text file: ./testing_texts/bg_316_p.txt
# Density: 0.5265
# Accuracy: 0.7842323651452282
# Loaded testing text file: ./testing_texts/bg_317_p.txt
# Density: 0.4645
# Accuracy: 0.7851239669421488
# Loaded testing text file: ./testing_texts/bg_318_p.txt
# Density: 0.356
# Accuracy: 0.7860082304526749
# Loaded testing text file: ./testing_texts/bg_319_p.txt
# Density: 0.414
# Accuracy: 0.7868852459016393
# Loaded testing text file: ./testing_texts/bg_31_p.txt
# Density: 0.202
# bul-->ces
# Accuracy: 0.7836734693877551
# Loaded testing text file: ./testing_texts/bg_320_p.txt
# Density: 0.5535
# Accuracy: 0.7845528455284553
# Loaded testing text file: ./testing_texts/bg_321_p.txt
# Density: 0.5075
# Accuracy: 0.7854251012145749
# Loaded testing text file: ./testing_texts/bg_322_p.txt
# Density: 0.357
# Accuracy: 0.7862903225806451
# Loaded testing text file: ./testing_texts/bg_323_p.txt
# Density: 0.5025
# bul-->slk
# Accuracy: 0.7831325301204819
# Loaded testing text file: ./testing_texts/bg_324_p.txt
# Density: 0.088
# Accuracy: 0.784
# Loaded testing text file: ./testing_texts/bg_325_p.txt
# Density: 0.587
# Accuracy: 0.7848605577689243
# Loaded testing text file: ./testing_texts/bg_326_p.txt
# Density: 0.497
# Accuracy: 0.7857142857142857
# Loaded testing text file: ./testing_texts/bg_327_p.txt
# Density: 0.178
# Accuracy: 0.7865612648221344
# Loaded testing text file: ./testing_texts/bg_328_p.txt
# Density: 0.1995
# bul-->hun
# Accuracy: 0.7834645669291339
# Loaded testing text file: ./testing_texts/bg_329_p.txt
# Density: 0.142
# Accuracy: 0.7843137254901961
# Loaded testing text file: ./testing_texts/bg_32_p.txt
# Density: 0.435
# Accuracy: 0.78515625
# Loaded testing text file: ./testing_texts/bg_330_p.txt
# Density: 0.344
# Accuracy: 0.7859922178988327
# Loaded testing text file: ./testing_texts/bg_331_p.txt
# Density: 0.5505
# Accuracy: 0.7868217054263565
# Loaded testing text file: ./testing_texts/bg_332_p.txt
# Density: 0.325
# Accuracy: 0.7876447876447876
# Loaded testing text file: ./testing_texts/bg_333_p.txt
# Density: 0.327
# Accuracy: 0.7884615384615384
# Loaded testing text file: ./testing_texts/bg_334_p.txt
# Density: 0.0985
# Accuracy: 0.789272030651341
# Loaded testing text file: ./testing_texts/bg_335_p.txt
# Density: 0.312
# Accuracy: 0.7900763358778626
# Loaded testing text file: ./testing_texts/bg_336_p.txt
# Density: 0.2875
# Accuracy: 0.7908745247148289
# Loaded testing text file: ./testing_texts/bg_337_p.txt
# Density: 0.494
# Accuracy: 0.7916666666666666
# Loaded testing text file: ./testing_texts/bg_338_p.txt
# Density: 0.531
# Accuracy: 0.7924528301886793
# Loaded testing text file: ./testing_texts/bg_339_p.txt
# Density: 0.3265
# bul-->ces
# Accuracy: 0.7894736842105263
# Loaded testing text file: ./testing_texts/bg_33_p.txt
# Density: 0.1225
# Accuracy: 0.7902621722846442
# Loaded testing text file: ./testing_texts/bg_340_p.txt
# Density: 0.2195
# bul-->slk
# Accuracy: 0.7873134328358209
# Loaded testing text file: ./testing_texts/bg_341_p.txt
# Density: 0.146
# Accuracy: 0.7881040892193308
# Loaded testing text file: ./testing_texts/bg_342_p.txt
# Density: 0.299
# Accuracy: 0.7888888888888889
# Loaded testing text file: ./testing_texts/bg_343_p.txt
# Density: 0.4845
# Accuracy: 0.7896678966789668
# Loaded testing text file: ./testing_texts/bg_344_p.txt
# Density: 0.291
# Accuracy: 0.7904411764705882
# Loaded testing text file: ./testing_texts/bg_345_p.txt
# Density: 0.661
# Accuracy: 0.7912087912087912
# Loaded testing text file: ./testing_texts/bg_346_p.txt
# Density: 0.1445
# bul-->ell
# Accuracy: 0.7883211678832117
# Loaded testing text file: ./testing_texts/bg_347_p.txt
# Density: 0.213
# Accuracy: 0.7890909090909091
# Loaded testing text file: ./testing_texts/bg_348_p.txt
# Density: 0.391
# Accuracy: 0.7898550724637681
# Loaded testing text file: ./testing_texts/bg_349_p.txt
# Density: 0.2385
# Accuracy: 0.7906137184115524
# Loaded testing text file: ./testing_texts/bg_34_p.txt
# Density: 0.2815
# Accuracy: 0.7913669064748201
# Loaded testing text file: ./testing_texts/bg_350_p.txt
# Density: 0.2455
# Accuracy: 0.7921146953405018
# Loaded testing text file: ./testing_texts/bg_351_p.txt
# Density: 0.6705
# Accuracy: 0.7928571428571428
# Loaded testing text file: ./testing_texts/bg_352_p.txt
# Density: 0.095
# Accuracy: 0.7935943060498221
# Loaded testing text file: ./testing_texts/bg_353_p.txt
# Density: 0.2535
# Accuracy: 0.7943262411347518
# Loaded testing text file: ./testing_texts/bg_354_p.txt
# Density: 0.4115
# Accuracy: 0.7950530035335689
# Loaded testing text file: ./testing_texts/bg_355_p.txt
# Density: 0.213
# bul-->slv
# Accuracy: 0.7922535211267606
# Loaded testing text file: ./testing_texts/bg_356_p.txt
# Density: 0.258
# Accuracy: 0.7929824561403509
# Loaded testing text file: ./testing_texts/bg_357_p.txt
# Density: 0.2175
# Accuracy: 0.7937062937062938
# Loaded testing text file: ./testing_texts/bg_358_p.txt
# Density: 0.238
# Accuracy: 0.794425087108014
# Loaded testing text file: ./testing_texts/bg_359_p.txt
# Density: 0.24
# bul-->spa
# Accuracy: 0.7916666666666666
# Loaded testing text file: ./testing_texts/bg_35_p.txt
# Density: 0.145
# bul-->slk
# Accuracy: 0.7889273356401384
# Loaded testing text file: ./testing_texts/bg_360_p.txt
# Density: 0.179
# Accuracy: 0.7896551724137931
# Loaded testing text file: ./testing_texts/bg_361_p.txt
# Density: 0.617
# Accuracy: 0.7903780068728522
# Loaded testing text file: ./testing_texts/bg_362_p.txt
# Density: 0.6715
# Accuracy: 0.791095890410959
# Loaded testing text file: ./testing_texts/bg_363_p.txt
# Density: 0.453
# Accuracy: 0.7918088737201365
# Loaded testing text file: ./testing_texts/bg_364_p.txt
# Density: 0.455
# Accuracy: 0.7925170068027211
# Loaded testing text file: ./testing_texts/bg_365_p.txt
# Density: 0.236
# Accuracy: 0.7932203389830509
# Loaded testing text file: ./testing_texts/bg_366_p.txt
# Density: 0.3545
# bul-->eng
# Accuracy: 0.7905405405405406
# Loaded testing text file: ./testing_texts/bg_367_p.txt
# Density: 0.383
# Accuracy: 0.7912457912457912
# Loaded testing text file: ./testing_texts/bg_368_p.txt
# Density: 0.3835
# Accuracy: 0.7919463087248322
# Loaded testing text file: ./testing_texts/bg_369_p.txt
# Density: 0.5815
# Accuracy: 0.7926421404682275
# Loaded testing text file: ./testing_texts/bg_36_p.txt
# Density: 0.328
# Accuracy: 0.7933333333333333
# Loaded testing text file: ./testing_texts/bg_370_p.txt
# Density: 0.3505
# Accuracy: 0.7940199335548173
# Loaded testing text file: ./testing_texts/bg_371_p.txt
# Density: 0.133
# bul-->est
# Accuracy: 0.7913907284768212
# Loaded testing text file: ./testing_texts/bg_372_p.txt
# Density: 0.442
# bul-->pol
# Accuracy: 0.7887788778877888
# Loaded testing text file: ./testing_texts/bg_373_p.txt
# Density: 0.437
# Accuracy: 0.7894736842105263
# Loaded testing text file: ./testing_texts/bg_374_p.txt
# Density: 0.351
# Accuracy: 0.7901639344262295
# Loaded testing text file: ./testing_texts/bg_375_p.txt
# Density: 0.4455
# Accuracy: 0.7908496732026143
# Loaded testing text file: ./testing_texts/bg_376_p.txt
# Density: 0.291
# Accuracy: 0.7915309446254072
# Loaded testing text file: ./testing_texts/bg_377_p.txt
# Density: 0.3305
# Accuracy: 0.7922077922077922
# Loaded testing text file: ./testing_texts/bg_378_p.txt
# Density: 0.395
# Accuracy: 0.7928802588996764
# Loaded testing text file: ./testing_texts/bg_379_p.txt
# Density: 0.1145
# Accuracy: 0.7935483870967742
# Loaded testing text file: ./testing_texts/bg_37_p.txt
# Density: 0.1665
# Accuracy: 0.7942122186495176
# Loaded testing text file: ./testing_texts/bg_380_p.txt
# Density: 0.128
# bul-->lav
# Accuracy: 0.7916666666666666
# Loaded testing text file: ./testing_texts/bg_381_p.txt
# Density: 0.6785
# bul-->fra
# Accuracy: 0.7891373801916933
# Loaded testing text file: ./testing_texts/bg_382_p.txt
# Density: 0.3495
# Accuracy: 0.7898089171974523
# Loaded testing text file: ./testing_texts/bg_383_p.txt
# Density: 0.4905
# Accuracy: 0.7904761904761904
# Loaded testing text file: ./testing_texts/bg_384_p.txt
# Density: 0.469
# Accuracy: 0.7911392405063291
# Loaded testing text file: ./testing_texts/bg_385_p.txt
# Density: 0.186
# Accuracy: 0.7917981072555205
# Loaded testing text file: ./testing_texts/bg_386_p.txt
# Density: 0.3635
# Accuracy: 0.7924528301886793
# Loaded testing text file: ./testing_texts/bg_387_p.txt
# Density: 0.34
# Accuracy: 0.7931034482758621
# Loaded testing text file: ./testing_texts/bg_388_p.txt
# Density: 0.407
# Accuracy: 0.79375
# Loaded testing text file: ./testing_texts/bg_389_p.txt
# Density: 0.2165
# Accuracy: 0.794392523364486
# Loaded testing text file: ./testing_texts/bg_38_p.txt
# Density: 0.2655
# bul-->nld
# Accuracy: 0.7919254658385093
# Loaded testing text file: ./testing_texts/bg_390_p.txt
# Density: 0.44
# Accuracy: 0.7925696594427245
# Loaded testing text file: ./testing_texts/bg_391_p.txt
# Density: 0.589
# Accuracy: 0.7932098765432098
# Loaded testing text file: ./testing_texts/bg_392_p.txt
# Density: 0.5
# Accuracy: 0.7938461538461539
# Loaded testing text file: ./testing_texts/bg_393_p.txt
# Density: 0.828
# Accuracy: 0.7944785276073619
# Loaded testing text file: ./testing_texts/bg_394_p.txt
# Density: 0.561
# Accuracy: 0.7951070336391437
# Loaded testing text file: ./testing_texts/bg_395_p.txt
# Density: 0.431
# Accuracy: 0.7957317073170732
# Loaded testing text file: ./testing_texts/bg_396_p.txt
# Density: 0.287
# Accuracy: 0.7963525835866262
# Loaded testing text file: ./testing_texts/bg_397_p.txt
# Density: 0.4235
# Accuracy: 0.796969696969697
# Loaded testing text file: ./testing_texts/bg_398_p.txt
# Density: 0.4485
# Accuracy: 0.797583081570997
# Loaded testing text file: ./testing_texts/bg_399_p.txt
# Density: 0.5015
# Accuracy: 0.7981927710843374
# Loaded testing text file: ./testing_texts/bg_39_p.txt
# Density: 0.158
# Accuracy: 0.7987987987987988
# Loaded testing text file: ./testing_texts/bg_3_p.txt
# Density: 0.258
# Accuracy: 0.7994011976047904
# Loaded testing text file: ./testing_texts/bg_400_p.txt
# Density: 0.3255
# bul-->ita
# Accuracy: 0.7970149253731343
# Loaded testing text file: ./testing_texts/bg_401_p.txt
# Density: 0.317
# Accuracy: 0.7976190476190477
# Loaded testing text file: ./testing_texts/bg_402_p.txt
# Density: 0.2725
# Accuracy: 0.798219584569733
# Loaded testing text file: ./testing_texts/bg_403_p.txt
# Density: 0.2855
# Accuracy: 0.7988165680473372
# Loaded testing text file: ./testing_texts/bg_404_p.txt
# Density: 0.205
# Accuracy: 0.799410029498525
# Loaded testing text file: ./testing_texts/bg_405_p.txt
# Density: 0.4635
# Accuracy: 0.8
# Loaded testing text file: ./testing_texts/bg_406_p.txt
# Density: 0.296
# Accuracy: 0.8005865102639296
# Loaded testing text file: ./testing_texts/bg_407_p.txt
# Density: 0.2895
# Accuracy: 0.8011695906432749
# Loaded testing text file: ./testing_texts/bg_408_p.txt
# Density: 0.254
# Accuracy: 0.8017492711370262
# Loaded testing text file: ./testing_texts/bg_409_p.txt
# Density: 0.545
# Accuracy: 0.8023255813953488
# Loaded testing text file: ./testing_texts/bg_40_p.txt
# Density: 0.1095
# bul-->por
# Accuracy: 0.8
# Loaded testing text file: ./testing_texts/bg_410_p.txt
# Density: 0.215
# Accuracy: 0.8005780346820809
# Loaded testing text file: ./testing_texts/bg_411_p.txt
# Density: 0.5625
# Accuracy: 0.8011527377521613
# Loaded testing text file: ./testing_texts/bg_412_p.txt
# Density: 0.2505
# Accuracy: 0.8017241379310345
# Loaded testing text file: ./testing_texts/bg_413_p.txt
# Density: 0.497
# Accuracy: 0.8022922636103151
# Loaded testing text file: ./testing_texts/bg_414_p.txt
# Density: 0.239
# Accuracy: 0.8028571428571428
# Loaded testing text file: ./testing_texts/bg_415_p.txt
# Density: 0.464
# Accuracy: 0.8034188034188035
# Loaded testing text file: ./testing_texts/bg_416_p.txt
# Density: 0.2935
# Accuracy: 0.8039772727272727
# Loaded testing text file: ./testing_texts/bg_417_p.txt
# Density: 0.402
# Accuracy: 0.8045325779036827
# Loaded testing text file: ./testing_texts/bg_418_p.txt
# Density: 0.286
# Accuracy: 0.8050847457627118
# Loaded testing text file: ./testing_texts/bg_419_p.txt
# Density: 0.481
# Accuracy: 0.8056338028169014
# Loaded testing text file: ./testing_texts/bg_41_p.txt
# Density: 0.1635
# Accuracy: 0.8061797752808989
# Loaded testing text file: ./testing_texts/bg_420_p.txt
# Density: 0.157
# Accuracy: 0.8067226890756303
# Loaded testing text file: ./testing_texts/bg_421_p.txt
# Density: 0.421
# Accuracy: 0.8072625698324022
# Loaded testing text file: ./testing_texts/bg_422_p.txt
# Density: 0.4535
# Accuracy: 0.807799442896936
# Loaded testing text file: ./testing_texts/bg_423_p.txt
# Density: 0.3875
# Accuracy: 0.8083333333333333
# Loaded testing text file: ./testing_texts/bg_424_p.txt
# Density: 0.2935
# Accuracy: 0.8088642659279779
# Loaded testing text file: ./testing_texts/bg_425_p.txt
# Density: 0.2945
# Accuracy: 0.8093922651933702
# Loaded testing text file: ./testing_texts/bg_426_p.txt
# Density: 0.3165
# Accuracy: 0.8099173553719008
# Loaded testing text file: ./testing_texts/bg_427_p.txt
# Density: 0.4245
# Accuracy: 0.8104395604395604
# Loaded testing text file: ./testing_texts/bg_428_p.txt
# Density: 0.1965
# bul-->slv
# Accuracy: 0.8082191780821918
# Loaded testing text file: ./testing_texts/bg_429_p.txt
# Density: 0.382
# Accuracy: 0.8087431693989071
# Loaded testing text file: ./testing_texts/bg_42_p.txt
# Density: 0.2695
# Accuracy: 0.8092643051771117
# Loaded testing text file: ./testing_texts/bg_430_p.txt
# Density: 0.3
# Accuracy: 0.8097826086956522
# Loaded testing text file: ./testing_texts/bg_431_p.txt
# Density: 0.2645
# Accuracy: 0.8102981029810298
# Loaded testing text file: ./testing_texts/bg_432_p.txt
# Density: 0.4465
# Accuracy: 0.8108108108108109
# Loaded testing text file: ./testing_texts/bg_433_p.txt
# Density: 0.4495
# Accuracy: 0.8113207547169812
# Loaded testing text file: ./testing_texts/bg_434_p.txt
# Density: 0.5135
# Accuracy: 0.8118279569892473
# Loaded testing text file: ./testing_texts/bg_435_p.txt
# Density: 0.682
# Accuracy: 0.8123324396782842
# Loaded testing text file: ./testing_texts/bg_436_p.txt
# Density: 0.519
# Accuracy: 0.8128342245989305
# Loaded testing text file: ./testing_texts/bg_437_p.txt
# Density: 0.451
# Accuracy: 0.8133333333333334
# Loaded testing text file: ./testing_texts/bg_438_p.txt
# Density: 0.207
# Accuracy: 0.8138297872340425
# Loaded testing text file: ./testing_texts/bg_439_p.txt
# Density: 0.382
# Accuracy: 0.8143236074270557
# Loaded testing text file: ./testing_texts/bg_43_p.txt
# Density: 0.3725
# Accuracy: 0.8148148148148148
# Loaded testing text file: ./testing_texts/bg_440_p.txt
# Density: 0.338
# Accuracy: 0.8153034300791556
# Loaded testing text file: ./testing_texts/bg_441_p.txt
# Density: 0.1385
# Accuracy: 0.8157894736842105
# Loaded testing text file: ./testing_texts/bg_442_p.txt
# Density: 0.65
# Accuracy: 0.8162729658792651
# Loaded testing text file: ./testing_texts/bg_443_p.txt
# Density: 0.362
# Accuracy: 0.8167539267015707
# Loaded testing text file: ./testing_texts/bg_444_p.txt
# Density: 0.4935
# Accuracy: 0.8172323759791122
# Loaded testing text file: ./testing_texts/bg_445_p.txt
# Density: 0.4235
# Accuracy: 0.8177083333333334
# Loaded testing text file: ./testing_texts/bg_446_p.txt
# Density: 0.163
# bul-->eng
# Accuracy: 0.8155844155844156
# Loaded testing text file: ./testing_texts/bg_447_p.txt
# Density: 0.18
# bul-->fin
# Accuracy: 0.8134715025906736
# Loaded testing text file: ./testing_texts/bg_448_p.txt
# Density: 0.245
# Accuracy: 0.813953488372093
# Loaded testing text file: ./testing_texts/bg_449_p.txt
# Density: 0.511
# Accuracy: 0.8144329896907216
# Loaded testing text file: ./testing_texts/bg_44_p.txt
# Density: 0.2455
# Accuracy: 0.8149100257069408
# Loaded testing text file: ./testing_texts/bg_450_p.txt
# Density: 0.5355
# Accuracy: 0.8153846153846154
# Loaded testing text file: ./testing_texts/bg_451_p.txt
# Density: 0.503
# Accuracy: 0.8158567774936062
# Loaded testing text file: ./testing_texts/bg_452_p.txt
# Density: 0.422
# Accuracy: 0.8163265306122449
# Loaded testing text file: ./testing_texts/bg_453_p.txt
# Density: 0.3625
# Accuracy: 0.816793893129771
# Loaded testing text file: ./testing_texts/bg_454_p.txt
# Density: 0.5945
# Accuracy: 0.817258883248731
# Loaded testing text file: ./testing_texts/bg_455_p.txt
# Density: 0.228
# bul-->slk
# Accuracy: 0.8151898734177215
# Loaded testing text file: ./testing_texts/bg_456_p.txt
# Density: 0.4125
# Accuracy: 0.8156565656565656
# Loaded testing text file: ./testing_texts/bg_457_p.txt
# Density: 0.603
# Accuracy: 0.8161209068010076
# Loaded testing text file: ./testing_texts/bg_458_p.txt
# Density: 0.4745
# Accuracy: 0.8165829145728644
# Loaded testing text file: ./testing_texts/bg_459_p.txt
# Density: 0.4565
# Accuracy: 0.8170426065162907
# Loaded testing text file: ./testing_texts/bg_45_p.txt
# Density: 0.439
# Accuracy: 0.8175
# Loaded testing text file: ./testing_texts/bg_460_p.txt
# Density: 0.5765
# Accuracy: 0.8179551122194514
# Loaded testing text file: ./testing_texts/bg_461_p.txt
# Density: 0.2195
# bul-->slv
# Accuracy: 0.8159203980099502
# Loaded testing text file: ./testing_texts/bg_462_p.txt
# Density: 0.2955
# bul-->slk
# Accuracy: 0.8138957816377171
# Loaded testing text file: ./testing_texts/bg_463_p.txt
# Density: 0.5335
# Accuracy: 0.8143564356435643
# Loaded testing text file: ./testing_texts/bg_464_p.txt
# Density: 0.428
# Accuracy: 0.8148148148148148
# Loaded testing text file: ./testing_texts/bg_465_p.txt
# Density: 0.459
# Accuracy: 0.8152709359605911
# Loaded testing text file: ./testing_texts/bg_466_p.txt
# Density: 0.333
# Accuracy: 0.8157248157248157
# Loaded testing text file: ./testing_texts/bg_467_p.txt
# Density: 0.1775
# bul-->est
# Accuracy: 0.8137254901960784
# Loaded testing text file: ./testing_texts/bg_468_p.txt
# Density: 0.22
# Accuracy: 0.8141809290953546
# Loaded testing text file: ./testing_texts/bg_469_p.txt
# Density: 0.4855
# Accuracy: 0.8146341463414634
# Loaded testing text file: ./testing_texts/bg_46_p.txt
# Density: 0.364
# bul-->hun
# Accuracy: 0.8126520681265207
# Loaded testing text file: ./testing_texts/bg_470_p.txt
# Density: 0.3635
# Accuracy: 0.8131067961165048
# Loaded testing text file: ./testing_texts/bg_471_p.txt
# Density: 0.3525
# Accuracy: 0.8135593220338984
# Loaded testing text file: ./testing_texts/bg_472_p.txt
# Density: 0.505
# Accuracy: 0.8140096618357487
# Loaded testing text file: ./testing_texts/bg_473_p.txt
# Density: 0.177
# bul-->ces
# Accuracy: 0.8120481927710843
# Loaded testing text file: ./testing_texts/bg_474_p.txt
# Density: 0.5045
# Accuracy: 0.8125
# Loaded testing text file: ./testing_texts/bg_475_p.txt
# Density: 0.601
# Accuracy: 0.8129496402877698
# Loaded testing text file: ./testing_texts/bg_476_p.txt
# Density: 0.346
# Accuracy: 0.8133971291866029
# Loaded testing text file: ./testing_texts/bg_477_p.txt
# Density: 0.3765
# Accuracy: 0.8138424821002387
# Loaded testing text file: ./testing_texts/bg_478_p.txt
# Density: 0.258
# Accuracy: 0.8142857142857143
# Loaded testing text file: ./testing_texts/bg_479_p.txt
# Density: 0.2455
# bul-->slv
# Accuracy: 0.8123515439429929
# Loaded testing text file: ./testing_texts/bg_47_p.txt
# Density: 0.534
# Accuracy: 0.8127962085308057
# Loaded testing text file: ./testing_texts/bg_480_p.txt
# Density: 0.4345
# Accuracy: 0.8132387706855791
# Loaded testing text file: ./testing_texts/bg_481_p.txt
# Density: 0.1835
# Accuracy: 0.8136792452830188
# Loaded testing text file: ./testing_texts/bg_482_p.txt
# Density: 0.42
# Accuracy: 0.8141176470588235
# Loaded testing text file: ./testing_texts/bg_483_p.txt
# Density: 0.2895
# Accuracy: 0.8145539906103286
# Loaded testing text file: ./testing_texts/bg_484_p.txt
# Density: 0.0555
# bul-->eng
# Accuracy: 0.8126463700234192
# Loaded testing text file: ./testing_texts/bg_485_p.txt
# Density: 0.307
# Accuracy: 0.8130841121495327
# Loaded testing text file: ./testing_texts/bg_486_p.txt
# Density: 0.3575
# bul-->slk
# Accuracy: 0.8111888111888111
# Loaded testing text file: ./testing_texts/bg_487_p.txt
# Density: 0.3635
# Accuracy: 0.8116279069767441
# Loaded testing text file: ./testing_texts/bg_488_p.txt
# Density: 0.2885
# bul-->slv
# Accuracy: 0.8097447795823666
# Loaded testing text file: ./testing_texts/bg_489_p.txt
# Density: 0.4145
# Accuracy: 0.8101851851851852
# Loaded testing text file: ./testing_texts/bg_48_p.txt
# Density: 0.6045
# Accuracy: 0.8106235565819861
# Loaded testing text file: ./testing_texts/bg_490_p.txt
# Density: 0.497
# Accuracy: 0.8110599078341014
# Loaded testing text file: ./testing_texts/bg_491_p.txt
# Density: 0.4105
# bul-->slk
# Accuracy: 0.8091954022988506
# Loaded testing text file: ./testing_texts/bg_492_p.txt
# Density: 0.233
# Accuracy: 0.8096330275229358
# Loaded testing text file: ./testing_texts/bg_493_p.txt
# Density: 0.41
# bul-->slk
# Accuracy: 0.8077803203661327
# Loaded testing text file: ./testing_texts/bg_494_p.txt
# Density: 0.2135
# Accuracy: 0.8082191780821918
# Loaded testing text file: ./testing_texts/bg_495_p.txt
# Density: 0.295
# Accuracy: 0.8086560364464692
# Loaded testing text file: ./testing_texts/bg_496_p.txt
# Density: 0.5925
# Accuracy: 0.8090909090909091
# Loaded testing text file: ./testing_texts/bg_497_p.txt
# Density: 0.401
# Accuracy: 0.8095238095238095
# Loaded testing text file: ./testing_texts/bg_498_p.txt
# Density: 0.367
# Accuracy: 0.8099547511312217
# Loaded testing text file: ./testing_texts/bg_499_p.txt
# Density: 0.3075
# Accuracy: 0.8103837471783296
# Loaded testing text file: ./testing_texts/bg_49_p.txt
# Density: 0.476
# Accuracy: 0.8108108108108109
# Loaded testing text file: ./testing_texts/bg_4_p.txt
# Density: 0.525
# Accuracy: 0.8112359550561797
# Loaded testing text file: ./testing_texts/bg_500_p.txt
# Density: 0.172
# bul-->hun
# Accuracy: 0.8094170403587444
# Loaded testing text file: ./testing_texts/bg_501_p.txt
# Density: 0.5815
# Accuracy: 0.8098434004474273
# Loaded testing text file: ./testing_texts/bg_502_p.txt
# Density: 0.585
# Accuracy: 0.8102678571428571
# Loaded testing text file: ./testing_texts/bg_503_p.txt
# Density: 0.277
# Accuracy: 0.8106904231625836
# Loaded testing text file: ./testing_texts/bg_504_p.txt
# Density: 0.454
# Accuracy: 0.8111111111111111
# Loaded testing text file: ./testing_texts/bg_505_p.txt
# Density: 0.6575
# Accuracy: 0.811529933481153
# Loaded testing text file: ./testing_texts/bg_506_p.txt
# Density: 0.375
# Accuracy: 0.8119469026548672
# Loaded testing text file: ./testing_texts/bg_507_p.txt
# Density: 0.4755
# Accuracy: 0.8123620309050773
# Loaded testing text file: ./testing_texts/bg_508_p.txt
# Density: 0.1675
# Accuracy: 0.8127753303964758
# Loaded testing text file: ./testing_texts/bg_509_p.txt
# Density: 0.391
# Accuracy: 0.8131868131868132
# Loaded testing text file: ./testing_texts/bg_50_p.txt
# Density: 0.216
# bul-->slv
# Accuracy: 0.8114035087719298
# Loaded testing text file: ./testing_texts/bg_510_p.txt
# Density: 0.4325
# Accuracy: 0.811816192560175
# Loaded testing text file: ./testing_texts/bg_511_p.txt
# Density: 0.41
# Accuracy: 0.8122270742358079
# Loaded testing text file: ./testing_texts/bg_512_p.txt
# Density: 0.5315
# bul-->slv
# Accuracy: 0.8104575163398693
# Loaded testing text file: ./testing_texts/bg_513_p.txt
# Density: 0.1595
# bul-->slk
# Accuracy: 0.808695652173913
# Loaded testing text file: ./testing_texts/bg_514_p.txt
# Density: 0.3155
# Accuracy: 0.8091106290672451
# Loaded testing text file: ./testing_texts/bg_515_p.txt
# Density: 0.1945
# bul-->slv
# Accuracy: 0.8073593073593074
# Loaded testing text file: ./testing_texts/bg_516_p.txt
# Density: 0.459
# Accuracy: 0.8077753779697624
# Loaded testing text file: ./testing_texts/bg_517_p.txt
# Density: 0.428
# Accuracy: 0.8081896551724138
# Loaded testing text file: ./testing_texts/bg_518_p.txt
# Density: 0.198
# Accuracy: 0.8086021505376344
# Loaded testing text file: ./testing_texts/bg_519_p.txt
# Density: 0.3765
# Accuracy: 0.8090128755364807
# Loaded testing text file: ./testing_texts/bg_51_p.txt
# Density: 0.543
# Accuracy: 0.8094218415417559
# Loaded testing text file: ./testing_texts/bg_520_p.txt
# Density: 0.2355
# Accuracy: 0.8098290598290598
# Loaded testing text file: ./testing_texts/bg_521_p.txt
# Density: 0.3045
# bul-->slv
# Accuracy: 0.8081023454157783
# Loaded testing text file: ./testing_texts/bg_522_p.txt
# Density: 0.119
# bul-->eng
# Accuracy: 0.8063829787234043
# Loaded testing text file: ./testing_texts/bg_523_p.txt
# Density: 0.421
# Accuracy: 0.8067940552016986
# Loaded testing text file: ./testing_texts/bg_524_p.txt
# Density: 0.3945
# bul-->slk
# Accuracy: 0.8050847457627118
# Loaded testing text file: ./testing_texts/bg_525_p.txt
# Density: 0.444
# Accuracy: 0.8054968287526427
# Loaded testing text file: ./testing_texts/bg_526_p.txt
# Density: 0.128
# bul-->slk
# Accuracy: 0.8037974683544303
# Loaded testing text file: ./testing_texts/bg_527_p.txt
# Density: 0.5565
# Accuracy: 0.8042105263157895
# Loaded testing text file: ./testing_texts/bg_528_p.txt
# Density: 0.3755
# Accuracy: 0.8046218487394958
# Loaded testing text file: ./testing_texts/bg_529_p.txt
# Density: 0.374
# Accuracy: 0.8050314465408805
# Loaded testing text file: ./testing_texts/bg_52_p.txt
# Density: 0.133
# Accuracy: 0.805439330543933
# Loaded testing text file: ./testing_texts/bg_530_p.txt
# Density: 0.218
# Accuracy: 0.8058455114822547
# ...
# Density: 0.234
# Accuracy: 0.7778150937964784
# Loaded testing text file: ./testing_texts/sv_860_p.txt
# Density: 0.6615
# Accuracy: 0.7778257532143542
# Loaded testing text file: ./testing_texts/sv_861_p.txt
# Density: 0.5195
# Accuracy: 0.7778364116094987
# Loaded testing text file: ./testing_texts/sv_862_p.txt
# Density: 0.2995
# Accuracy: 0.7778470689820589
# Loaded testing text file: ./testing_texts/sv_863_p.txt
# Density: 0.1825
# Accuracy: 0.7778577253321821
# Loaded testing text file: ./testing_texts/sv_864_p.txt
# Density: 0.3695
# Accuracy: 0.7778683806600154
# Loaded testing text file: ./testing_texts/sv_865_p.txt
# Density: 0.4755
# Accuracy: 0.7778790349657058
# Loaded testing text file: ./testing_texts/sv_866_p.txt
# Density: 0.5275
# Accuracy: 0.7778896882494005
# Loaded testing text file: ./testing_texts/sv_867_p.txt
# Density: 0.536
# Accuracy: 0.7779003405112465
# Loaded testing text file: ./testing_texts/sv_868_p.txt
# Density: 0.076
# swe-->dan
# Accuracy: 0.7778630347208901
# Loaded testing text file: ./testing_texts/sv_869_p.txt
# Density: 0.4745
# Accuracy: 0.7778736872392461
# Loaded testing text file: ./testing_texts/sv_86_p.txt
# Density: 0.2845
# swe-->fin
# Accuracy: 0.7778363863047857
# Loaded testing text file: ./testing_texts/sv_870_p.txt
# Density: 0.4985
# Accuracy: 0.7778470390793575
# Loaded testing text file: ./testing_texts/sv_871_p.txt
# Density: 0.5025
# Accuracy: 0.7778576908323743
# Loaded testing text file: ./testing_texts/sv_872_p.txt
# Density: 0.1345
# swe-->spa
# Accuracy: 0.7778203960301098
# Loaded testing text file: ./testing_texts/sv_873_p.txt
# Density: 0.4605
# Accuracy: 0.7778310480391217
# Loaded testing text file: ./testing_texts/sv_874_p.txt
# Density: 0.6065
# Accuracy: 0.777841699026799
# Loaded testing text file: ./testing_texts/sv_875_p.txt
# Density: 0.448
# Accuracy: 0.7778523489932886
# Loaded testing text file: ./testing_texts/sv_876_p.txt
# Density: 0.3785
# Accuracy: 0.7778629979387374
# Loaded testing text file: ./testing_texts/sv_877_p.txt
# Density: 0.2645
# Accuracy: 0.7778736458632921
# Loaded testing text file: ./testing_texts/sv_878_p.txt
# Density: 0.379
# Accuracy: 0.7778842927670997
# Loaded testing text file: ./testing_texts/sv_879_p.txt
# Density: 0.3555
# Accuracy: 0.7778949386503068
# Loaded testing text file: ./testing_texts/sv_87_p.txt
# Density: 0.3525
# Accuracy: 0.7779055835130602
# Loaded testing text file: ./testing_texts/sv_880_p.txt
# Density: 0.4025
# swe-->slk
# Accuracy: 0.7778683025016774
# Loaded testing text file: ./testing_texts/sv_881_p.txt
# Density: 0.2415
# swe-->eng
# Accuracy: 0.7778310250634974
# Loaded testing text file: ./testing_texts/sv_882_p.txt
# Density: 0.3715
# swe-->nld
# Accuracy: 0.7777937511980065
# Loaded testing text file: ./testing_texts/sv_883_p.txt
# Density: 0.322
# swe-->fra
# Accuracy: 0.7777564809046912
# Loaded testing text file: ./testing_texts/sv_884_p.txt
# Density: 0.4285
# Accuracy: 0.7777671298514615
# Loaded testing text file: ./testing_texts/sv_885_p.txt
# Density: 0.1295
# swe-->dan
# Accuracy: 0.7777298644051555
# Loaded testing text file: ./testing_texts/sv_886_p.txt
# Density: 0.3635
# swe-->eng
# Accuracy: 0.7776926025297048
# Loaded testing text file: ./testing_texts/sv_887_p.txt
# Density: 0.354
# Accuracy: 0.7777032530062761
# Loaded testing text file: ./testing_texts/sv_888_p.txt
# Density: 0.163
# swe-->dan
# Accuracy: 0.7776659959758552
# Loaded testing text file: ./testing_texts/sv_889_p.txt
# Density: 0.3675
# Accuracy: 0.7776766467065869
# Loaded testing text file: ./testing_texts/sv_88_p.txt
# Density: 0.077
# swe-->est
# Accuracy: 0.777639394520023
# Loaded testing text file: ./testing_texts/sv_890_p.txt
# Density: 0.5735
# Accuracy: 0.7776500455046224
# Loaded testing text file: ./testing_texts/sv_891_p.txt
# Density: 0.108
# Accuracy: 0.7776606954689147
# Loaded testing text file: ./testing_texts/sv_892_p.txt
# Density: 0.4145
# Accuracy: 0.7776713444130466
# Loaded testing text file: ./testing_texts/sv_893_p.txt
# Density: 0.456
# Accuracy: 0.7776819923371647
# Loaded testing text file: ./testing_texts/sv_894_p.txt
# Density: 0.2975
# Accuracy: 0.7776926392414156
# Loaded testing text file: ./testing_texts/sv_895_p.txt
# Density: 0.2335
# Accuracy: 0.7777032851259458
# Loaded testing text file: ./testing_texts/sv_896_p.txt
# Density: 0.4005
# Accuracy: 0.7777139299909017
# Loaded testing text file: ./testing_texts/sv_897_p.txt
# Density: 0.2955
# Accuracy: 0.7777245738364298
# Loaded testing text file: ./testing_texts/sv_898_p.txt
# Density: 0.0995
# Accuracy: 0.7777352166626765
# Loaded testing text file: ./testing_texts/sv_899_p.txt
# Density: 0.3455
# swe-->dan
# Accuracy: 0.7776979795078043
# Loaded testing text file: ./testing_texts/sv_89_p.txt
# Density: 0.1025
# swe-->est
# Accuracy: 0.7776607459185139
# Loaded testing text file: ./testing_texts/sv_8_p.txt
# Density: 0.2965
# Accuracy: 0.7776713902719264
# Loaded testing text file: ./testing_texts/sv_900_p.txt
# Density: 0.348
# Accuracy: 0.7776820336062042
# Loaded testing text file: ./testing_texts/sv_901_p.txt
# Density: 0.226
# swe-->deu
# Accuracy: 0.7776448061273337
# Loaded testing text file: ./testing_texts/sv_902_p.txt
# Density: 0.206
# swe-->deu
# Accuracy: 0.777607582212436
# Loaded testing text file: ./testing_texts/sv_903_p.txt
# Density: 0.352
# Accuracy: 0.7776182270725637
# Loaded testing text file: ./testing_texts/sv_904_p.txt
# Density: 0.0995
# Accuracy: 0.7776288709137031
# Loaded testing text file: ./testing_texts/sv_905_p.txt
# Density: 0.29
# swe-->dan
# Accuracy: 0.7775916531061549
# Loaded testing text file: ./testing_texts/sv_906_p.txt
# Density: 0.3225
# Accuracy: 0.7776022972002872
# Loaded testing text file: ./testing_texts/sv_907_p.txt
# Density: 0.3225
# Accuracy: 0.7776129402756509
# Loaded testing text file: ./testing_texts/sv_908_p.txt
# Density: 0.43
# Accuracy: 0.7776235823323923
# Loaded testing text file: ./testing_texts/sv_909_p.txt
# Density: 0.5515
# Accuracy: 0.7776342233706575
# Loaded testing text file: ./testing_texts/sv_90_p.txt
# Density: 0.1965
# Accuracy: 0.7776448633905928
# Loaded testing text file: ./testing_texts/sv_910_p.txt
# Density: 0.283
# Accuracy: 0.7776555023923445
# Loaded testing text file: ./testing_texts/sv_911_p.txt
# Density: 0.3315
# Accuracy: 0.7776661403760585
# Loaded testing text file: ./testing_texts/sv_912_p.txt
# Density: 0.4465
# Accuracy: 0.7776767773418811
# Loaded testing text file: ./testing_texts/sv_913_p.txt
# Density: 0.359
# Accuracy: 0.7776874132899584
# Loaded testing text file: ./testing_texts/sv_914_p.txt
# Density: 0.393
# Accuracy: 0.7776980482204363
# Loaded testing text file: ./testing_texts/sv_915_p.txt
# Density: 0.438
# Accuracy: 0.7777086821334609
# Loaded testing text file: ./testing_texts/sv_916_p.txt
# Density: 0.461
# Accuracy: 0.7777193150291782
# Loaded testing text file: ./testing_texts/sv_917_p.txt
# Density: 0.4735
# Accuracy: 0.7777299469077342
# Loaded testing text file: ./testing_texts/sv_918_p.txt
# Density: 0.2815
# Accuracy: 0.777740577769275
# Loaded testing text file: ./testing_texts/sv_919_p.txt
# Density: 0.344
# swe-->ita
# Accuracy: 0.7777033813190493
# Loaded testing text file: ./testing_texts/sv_91_p.txt
# Density: 0.41
# swe-->bul
# Accuracy: 0.7776661884265902
# Loaded testing text file: ./testing_texts/sv_920_p.txt
# Density: 0.1885
# Accuracy: 0.7776768208120128
# Loaded testing text file: ./testing_texts/sv_921_p.txt
# Density: 0.528
# Accuracy: 0.7776874521805662
# Loaded testing text file: ./testing_texts/sv_922_p.txt
# Density: 0.459
# Accuracy: 0.7776980825323961
# Loaded testing text file: ./testing_texts/sv_923_p.txt
# Density: 0.455
# Accuracy: 0.7777087118676485
# Loaded testing text file: ./testing_texts/sv_924_p.txt
# Density: 0.5945
# swe-->deu
# Accuracy: 0.777671527611762
# Loaded testing text file: ./testing_texts/sv_925_p.txt
# Density: 0.3905
# Accuracy: 0.7776821572002295
# Loaded testing text file: ./testing_texts/sv_926_p.txt
# Density: 0.2855
# Accuracy: 0.7776927857723382
# Loaded testing text file: ./testing_texts/sv_927_p.txt
# Density: 0.606
# Accuracy: 0.777703413328234
# Loaded testing text file: ./testing_texts/sv_928_p.txt
# Density: 0.28
# swe-->deu
# Accuracy: 0.777666236435776
# Loaded testing text file: ./testing_texts/sv_929_p.txt
# Density: 0.118
# swe-->eng
# Accuracy: 0.7776290630975143
# Loaded testing text file: ./testing_texts/sv_92_p.txt
# Density: 0.342
# Accuracy: 0.7776396921753262
# Loaded testing text file: ./testing_texts/sv_930_p.txt
# Density: 0.216
# Accuracy: 0.777650320237071
# Loaded testing text file: ./testing_texts/sv_931_p.txt
# Density: 0.3815
# Accuracy: 0.7776609472828945
# Loaded testing text file: ./testing_texts/sv_932_p.txt
# Density: 0.397
# Accuracy: 0.7776715733129421
# Loaded testing text file: ./testing_texts/sv_933_p.txt
# Density: 0.3555
# Accuracy: 0.7776821983273596
# Loaded testing text file: ./testing_texts/sv_934_p.txt
# Density: 0.3815
# swe-->eng
# Accuracy: 0.7776450348848323
# Loaded testing text file: ./testing_texts/sv_935_p.txt
# Density: 0.7
# Accuracy: 0.7776556601519568
# Loaded testing text file: ./testing_texts/sv_936_p.txt
# Density: 0.4965
# Accuracy: 0.7776662844036697
# Loaded testing text file: ./testing_texts/sv_937_p.txt
# Density: 0.388
# Accuracy: 0.7776769076401165
# Loaded testing text file: ./testing_texts/sv_938_p.txt
# Density: 0.2365
# Accuracy: 0.7776875298614428
# Loaded testing text file: ./testing_texts/sv_939_p.txt
# Density: 0.3475
# Accuracy: 0.7776981510677942
# Loaded testing text file: ./testing_texts/sv_93_p.txt
# Density: 0.487
# swe-->dan
# Accuracy: 0.7776609975157653
# Loaded testing text file: ./testing_texts/sv_940_p.txt
# Density: 0.4405
# Accuracy: 0.7776716189748244
# Loaded testing text file: ./testing_texts/sv_941_p.txt
# Density: 0.3855
# swe-->dan
# Accuracy: 0.7776344702398013
# Loaded testing text file: ./testing_texts/sv_942_p.txt
# Density: 0.5155
# Accuracy: 0.7776450919512777
# Loaded testing text file: ./testing_texts/sv_943_p.txt
# Density: 0.3105
# Accuracy: 0.7776557126480703
# Loaded testing text file: ./testing_texts/sv_944_p.txt
# Density: 0.341
# swe-->dan
# Accuracy: 0.7776185699957013
# Loaded testing text file: ./testing_texts/sv_945_p.txt
# Density: 0.3105
# swe-->dan
# Accuracy: 0.7775814308912026
# Loaded testing text file: ./testing_texts/sv_946_p.txt
# Density: 0.283
# swe-->nld
# Accuracy: 0.7775442953340657
# Loaded testing text file: ./testing_texts/sv_947_p.txt
# Density: 0.5565
# Accuracy: 0.7775549188156639
# Loaded testing text file: ./testing_texts/sv_948_p.txt
# Density: 0.175
# Accuracy: 0.7775655412826512
# Loaded testing text file: ./testing_texts/sv_949_p.txt
# Density: 0.5695
# Accuracy: 0.7775761627351734
# Loaded testing text file: ./testing_texts/sv_94_p.txt
# Density: 0.181
# Accuracy: 0.7775867831733754
# Loaded testing text file: ./testing_texts/sv_950_p.txt
# Density: 0.2775
# swe-->eng
# Accuracy: 0.7775496562261268
# Loaded testing text file: ./testing_texts/sv_951_p.txt
# Density: 0.428
# Accuracy: 0.7775602769157317
# Loaded testing text file: ./testing_texts/sv_952_p.txt
# Density: 0.389
# swe-->est
# Accuracy: 0.7775231547789554
# Loaded testing text file: ./testing_texts/sv_953_p.txt
# Density: 0.3665
# Accuracy: 0.7775337757196734
# Loaded testing text file: ./testing_texts/sv_954_p.txt
# Density: 0.5095
# Accuracy: 0.7775443956463625
# Loaded testing text file: ./testing_texts/sv_955_p.txt
# Density: 0.3275
# Accuracy: 0.7775550145591675
# Loaded testing text file: ./testing_texts/sv_956_p.txt
# Density: 0.174
# swe-->eng
# Accuracy: 0.7775178997613366
# Loaded testing text file: ./testing_texts/sv_957_p.txt
# Density: 0.3595
# Accuracy: 0.777528518925111
# Loaded testing text file: ./testing_texts/sv_958_p.txt
# Density: 0.3295
# Accuracy: 0.7775391370752196
# Loaded testing text file: ./testing_texts/sv_959_p.txt
# Density: 0.3945
# Accuracy: 0.7775497542118074
# Loaded testing text file: ./testing_texts/sv_95_p.txt
# Density: 0.365
# Accuracy: 0.7775603703350196
# Loaded testing text file: ./testing_texts/sv_960_p.txt
# Density: 0.4275
# Accuracy: 0.7775709854450011
# Loaded testing text file: ./testing_texts/sv_961_p.txt
# Density: 0.4765
# Accuracy: 0.7775815995418973
# Loaded testing text file: ./testing_texts/sv_962_p.txt
# Density: 0.461
# Accuracy: 0.777592212625853
# Loaded testing text file: ./testing_texts/sv_963_p.txt
# Density: 0.3835
# Accuracy: 0.777602824697013
# Loaded testing text file: ./testing_texts/sv_964_p.txt
# Density: 0.3695
# Accuracy: 0.7776134357555227
# Loaded testing text file: ./testing_texts/sv_965_p.txt
# Density: 0.233
# swe-->est
# Accuracy: 0.7775763358778626
# Loaded testing text file: ./testing_texts/sv_966_p.txt
# Density: 0.2235
# Accuracy: 0.7775869471876342
# Loaded testing text file: ./testing_texts/sv_967_p.txt
# Density: 0.404
# Accuracy: 0.7775975574849728
# Loaded testing text file: ./testing_texts/sv_968_p.txt
# Density: 0.3465
# Accuracy: 0.7776081667700234
# Loaded testing text file: ./testing_texts/sv_969_p.txt
# Density: 0.612
# Accuracy: 0.7776187750429308
# Loaded testing text file: ./testing_texts/sv_96_p.txt
# Density: 0.491
# Accuracy: 0.7776293823038397
# Loaded testing text file: ./testing_texts/sv_970_p.txt
# Density: 0.3805
# Accuracy: 0.7776399885528952
# Loaded testing text file: ./testing_texts/sv_971_p.txt
# Density: 0.3545
# Accuracy: 0.7776505937902418
# Loaded testing text file: ./testing_texts/sv_972_p.txt
# Density: 0.0815
# swe-->est
# Accuracy: 0.7776135062953071
# Loaded testing text file: ./testing_texts/sv_973_p.txt
# Density: 0.4785
# Accuracy: 0.7776241117840622
# Loaded testing text file: ./testing_texts/sv_974_p.txt
# Density: 0.246
# Accuracy: 0.7776347162613257
# Loaded testing text file: ./testing_texts/sv_975_p.txt
# Density: 0.2825
# swe-->dan
# Accuracy: 0.7775976348290496
# Loaded testing text file: ./testing_texts/sv_976_p.txt
# Density: 0.4775
# Accuracy: 0.7776082395575052
# Loaded testing text file: ./testing_texts/sv_977_p.txt
# Density: 0.503
# Accuracy: 0.7776188432746866
# Loaded testing text file: ./testing_texts/sv_978_p.txt
# Density: 0.294
# Accuracy: 0.777629445980738
# Loaded testing text file: ./testing_texts/sv_979_p.txt
# Density: 0.432
# Accuracy: 0.7776400476758045
# Loaded testing text file: ./testing_texts/sv_97_p.txt
# Density: 0.2545
# swe-->dan
# Accuracy: 0.7776029748283753
# Loaded testing text file: ./testing_texts/sv_980_p.txt
# Density: 0.412
# Accuracy: 0.7776135767745627
# Loaded testing text file: ./testing_texts/sv_981_p.txt
# Density: 0.0925
# swe-->fra
# Accuracy: 0.7775765087234245
# Loaded testing text file: ./testing_texts/sv_982_p.txt
# Density: 0.141
# swe-->nld
# Accuracy: 0.7775394442061109
# Loaded testing text file: ./testing_texts/sv_983_p.txt
# Density: 0.293
# Accuracy: 0.7775500476644424
# Loaded testing text file: ./testing_texts/sv_984_p.txt
# Density: 0.2275
# Accuracy: 0.7775606501120061
# Loaded testing text file: ./testing_texts/sv_985_p.txt
# Density: 0.2805
# swe-->eng
# Accuracy: 0.7775235916499857
# Loaded testing text file: ./testing_texts/sv_986_p.txt
# Density: 0.3935
# Accuracy: 0.7775341943478054
# Loaded testing text file: ./testing_texts/sv_987_p.txt
# Density: 0.198
# swe-->fin
# Accuracy: 0.7774971406786123
# Loaded testing text file: ./testing_texts/sv_988_p.txt
# Density: 0.3865
# Accuracy: 0.7775077436263998
# Loaded testing text file: ./testing_texts/sv_989_p.txt
# Density: 0.3035
# swe-->dan
# Accuracy: 0.7774706947488802
# Loaded testing text file: ./testing_texts/sv_98_p.txt
# Density: 0.124
# swe-->eng
# Accuracy: 0.7774336494020108
# Loaded testing text file: ./testing_texts/sv_990_p.txt
# Density: 0.5495
# Accuracy: 0.7774442538593482
# Loaded testing text file: ./testing_texts/sv_991_p.txt
# Density: 0.6605
# Accuracy: 0.777454857306208
# Loaded testing text file: ./testing_texts/sv_992_p.txt
# Density: 0.3635
# Accuracy: 0.7774654597427346
# Loaded testing text file: ./testing_texts/sv_993_p.txt
# Density: 0.4375
# Accuracy: 0.7774760611690724
# Loaded testing text file: ./testing_texts/sv_994_p.txt
# Density: 0.622
# Accuracy: 0.7774866615853658
# Loaded testing text file: ./testing_texts/sv_995_p.txt
# Density: 0.345
# Accuracy: 0.7774972609917592
# Loaded testing text file: ./testing_texts/sv_996_p.txt
# Density: 0.5
# Accuracy: 0.7775078593883967
# Loaded testing text file: ./testing_texts/sv_997_p.txt
# Density: 0.375
# Accuracy: 0.7775184567754228
# Loaded testing text file: ./testing_texts/sv_998_p.txt
# Density: 0.2195
# swe-->fin
# Accuracy: 0.7774814250333397
# Loaded testing text file: ./testing_texts/sv_999_p.txt
# Density: 0.2195
# swe-->est
# Accuracy: 0.7774443968185931
# Loaded testing text file: ./testing_texts/sv_99_p.txt
# Density: 0.308
# Accuracy: 0.7774549957138776
# Loaded testing text file: ./testing_texts/sv_9_p.txt
# Density: 0.267
# Accuracy: 0.7774655935996952
# 0.7774655935996952

# %%
# item_mem = np.load('item_mem_all_500.npy', allow_pickle='TRUE').item()
# lang_am = np.load('lang_am_all_500_full.npy', allow_pickle='TRUE').item()
# item_mem = np.load('old_data/item_mem_all.npy', allow_pickle='TRUE').item() // this one has 10% IM density for D=10000
# lang_am = np.load('old_data/lang_am_all.npy', allow_pickle='TRUE').item()

# test = lang_am_full['bul'].copy()

# lang_am['afr'] = binarize_hv_thr(lang_am_full['afr'], 0.03*949192)
# lang_am['bul'] = binarize_hv_thr(test, 0.025*1074672)
# lang_am['afr'] = binarize_hv_sort(lang_am['afr'], 0.06)
# lang_am['bul'] = binarize_hv_sort(lang_am['bul'], 0.06)
# for i in lang_am.keys():
#   lang_am[i] = binarize_hv_sort(lang_am[i], 0.3)
# print(np.sum(item_mem['a'])/D)
# test = [1,3,4,4]
# arr = np.array(test)
# print(arr)
# a = arr.copy()
# arr[0] = 3
# print(a)

# %%
for i in lang_am:
  print(i + ':' + str(np.sum(lang_am[i])/D))
# for i in item_mem:
#   print(str(np.sum(item_mem[i])/D))
# Out:
# bul:0.5
# ces:0.5
# dan:0.5
# nld:0.5
# deu:0.5005
# eng:0.5005
# est:0.5
# fin:0.5005
# fra:0.5
# ell:0.5
# hun:0.5
# ita:0.5
# lav:0.5
# lit:0.5
# pol:0.5
# por:0.5
# ron:0.5
# slk:0.501
# slv:0.5
# spa:0.5
# swe:0.5
